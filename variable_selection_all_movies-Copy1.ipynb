# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import itertools
import time
movies = pd.read_csv('movie_industry_clean.csv')

# %%
# data wrangling
def wrangling(df):
    df = df.drop('Unnamed: 0', axis=1)
    df = df.drop('index', axis=1)
    df.replace(' ', '_', regex=True, inplace = True)
    df.replace('-', '_', regex=True, inplace = True)
    return df

movies = wrangling(movies)

# %%
# grouping countries into continents
def continent(s):
    if s['country'] in ['United_States','Mexico', 'Canada','Jamaica']:
        return 'North_America'
    if s['country'] in ['United_Kingdom', 'France', 'Germany', 'Belgium','Spain', 'Norway', 'Iceland', 'West_Germany', 'Ireland', 'Italy', 'Finland', 'Czech_Republic', 'Switzerland', 'Sweden', 'Denmark', 'Netherlands','Federal_Republic_of_Yugoslavia','Yugoslavia', 'Hungary', 'Republic_of_Macedonia', 'Austria','Portugal','Malta']:
        return 'Europe'
    if s['country'] in ['Japan','China','South_Korea', 'Hong_Kong','India','United_Arab_Emirates','Taiwan','Lebanon','Indonesia', 'Iran','Israel','Russia','Thailand']:
        return 'Asia'
    if s['country'] in ['Australia','New_Zealand']:
        return 'Oceania'
    if s['country'] in ['South_Africa', 'Kenya']:
        return 'Africa'
    if s['country'] in ['Brazil', 'Argentina', 'Aruba', 'Chile', 'Panama','Colombia']:
        return 'South_America'
    else:
        return 'NA'

movies['continent'] = movies.apply(continent, axis=1)

# %%
movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The_Shining          R      Drama
# 1                                    The_Blue_Lagoon          R  Adventure
# 2     Star_Wars:_Episode_V___The_Empire_Strikes_Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad_Boys_for_Life          R     Action
# 5417                              Sonic_the_Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The_Call_of_the_Wild         PG  Adventure
# 5420                               The_Eight_Hundred  Not_Rated     Action
#
#       year                           released  score      votes  \
# 0     1980      June_13,_1980_(United_States)    8.4   927000.0
# 1     1980       July_2,_1980_(United_States)    5.8    65000.0
# 2     1980      June_20,_1980_(United_States)    8.7  1200000.0
# 3     1980       July_2,_1980_(United_States)    7.7   221000.0
# 4     1980      July_25,_1980_(United_States)    7.3   108000.0
# ...    ...                                ...    ...        ...
# 5416  2020   January_17,_2020_(United_States)    6.6   140000.0
# 5417  2020  February_14,_2020_(United_States)    6.5   102000.0
# 5418  2020   January_17,_2020_(United_States)    5.6    53000.0
# 5419  2020  February_21,_2020_(United_States)    6.8    42000.0
# 5420  2020    August_28,_2020_(United_States)    6.8     3700.0
#
#              director                   writer               star  \
# 0     Stanley_Kubrick             Stephen_King     Jack_Nicholson
# 1      Randal_Kleiser  Henry_De_Vere_Stacpoole     Brooke_Shields
# 2      Irvin_Kershner           Leigh_Brackett        Mark_Hamill
# 3        Jim_Abrahams             Jim_Abrahams        Robert_Hays
# 4        Harold_Ramis       Brian_Doyle_Murray        Chevy_Chase
# ...               ...                      ...                ...
# 5416     Adil_El_Arbi              Peter_Craig         Will_Smith
# 5417      Jeff_Fowler                Pat_Casey       Ben_Schwartz
# 5418   Stephen_Gaghan           Stephen_Gaghan  Robert_Downey_Jr.
# 5419    Chris_Sanders            Michael_Green      Harrison_Ford
# 5420          Hu_Guan                  Hu_Guan    Zhi_zhong_Huang
#
#              country       budget        gross  \
# 0     United_Kingdom   19000000.0   46998772.0
# 1      United_States    4500000.0   58853106.0
# 2      United_States   18000000.0  538375067.0
# 3      United_States    3500000.0   83453539.0
# 4      United_States    6000000.0   39846344.0
# ...              ...          ...          ...
# 5416   United_States   90000000.0  426505244.0
# 5417   United_States   85000000.0  319715683.0
# 5418   United_States  175000000.0  245487753.0
# 5419          Canada  135000000.0  111105497.0
# 5420           China   80000000.0  461421559.0
#
#                                   company  runtime
# 0                            Warner_Bros.    146.0
# 1                       Columbia_Pictures    104.0
# 2                               Lucasfilm    124.0
# 3                      Paramount_Pictures     88.0
# 4                          Orion_Pictures     98.0
# ...                                   ...      ...
# 5416                    Columbia_Pictures    124.0
# 5417                   Paramount_Pictures     99.0
# 5418                   Universal_Pictures    101.0
# 5419                 20th_Century_Studios    100.0
# 5420  Beijing_Diqi_Yinxiang_Entertainment    149.0
#
# [5421 rows x 15 columns]

# %%
movies.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5421.000000  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03
# mean   2001.661317     6.392455  1.150661e+05  3.600917e+07  1.032297e+08
# std      10.540908     0.962730  1.844073e+05  4.157337e+07  1.873027e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.073640e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.180000e+07  3.686941e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.124625e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  5421.000000
# mean    108.152739
# std      18.115698
# min      63.000000
# 25%      95.000000
# 50%     105.000000
# 75%     118.000000
# max     271.000000

# %%
# split into training & test
np.random.seed(2)
train = movies.sample(round(movies.shape[0]*0.8)) # 80%
test = movies.drop(train.index)

# %% [markdown]
# ## INITIAL EDA (incomplete, can be built off of)

# %% [markdown]
# ### MODEL WITHOUT TRANFORMATIONS

# %%
# the start of a model by hand - NO INTERACTIONS/TRANSFORMATIONS

ols_object = smf.ols(formula = 'gross~budget+genre+rating+votes+continent+runtime+score+year', data = train)
model = ols_object.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     272.6
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        11:33:42   Log-Likelihood:                -86289.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4303   BIC:                         1.729e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -5.257e+08   3.63e+08     -1.448      0.148   -1.24e+09    1.86e+08
# genre[T.Adventure]          6.217e+06   7.74e+06      0.803      0.422   -8.97e+06    2.14e+07
# genre[T.Animation]          6.414e+07   1.01e+07      6.336      0.000    4.43e+07     8.4e+07
# genre[T.Biography]         -1.005e+07   8.08e+06     -1.243      0.214   -2.59e+07    5.79e+06
# genre[T.Comedy]             1.418e+07   4.74e+06      2.992      0.003    4.89e+06    2.35e+07
# genre[T.Crime]             -2.856e+06   7.08e+06     -0.404      0.687   -1.67e+07     1.1e+07
# genre[T.Drama]              1.931e+06   5.63e+06      0.343      0.731    -9.1e+06     1.3e+07
# genre[T.Family]             4.694e+08   6.16e+07      7.621      0.000    3.49e+08     5.9e+08
# genre[T.Fantasy]             2.11e+07   2.01e+07      1.050      0.294   -1.83e+07    6.05e+07
# genre[T.Horror]             4.058e+07   8.46e+06      4.797      0.000     2.4e+07    5.72e+07
# genre[T.Mystery]            1.333e+07   3.09e+07      0.431      0.666   -4.73e+07    7.39e+07
# genre[T.Romance]           -1.125e+07   5.34e+07     -0.211      0.833   -1.16e+08    9.34e+07
# genre[T.Sci_Fi]            -2.413e+07   4.35e+07     -0.554      0.579   -1.09e+08    6.12e+07
# genre[T.Thriller]           3.862e+07   4.36e+07      0.887      0.375   -4.68e+07    1.24e+08
# genre[T.Western]           -3.608e+06   1.06e+08     -0.034      0.973   -2.12e+08    2.05e+08
# rating[T.G]                -7.332e+07   1.07e+08     -0.683      0.495   -2.84e+08    1.37e+08
# rating[T.NC_17]            -7.814e+07   1.12e+08     -0.698      0.485   -2.98e+08    1.41e+08
# rating[T.Not_Rated]        -5.937e+07   1.08e+08     -0.548      0.584   -2.72e+08    1.53e+08
# rating[T.PG]               -5.853e+07   1.07e+08     -0.549      0.583   -2.68e+08    1.51e+08
# rating[T.PG_13]            -6.984e+07   1.07e+08     -0.654      0.513   -2.79e+08    1.39e+08
# rating[T.R]                -8.442e+07   1.07e+08     -0.791      0.429   -2.94e+08    1.25e+08
# rating[T.TV_MA]            -9.248e+07   1.51e+08     -0.613      0.540   -3.88e+08    2.03e+08
# rating[T.Unrated]          -5.807e+07   1.11e+08     -0.523      0.601   -2.76e+08     1.6e+08
# rating[T.X]                -1.215e+08   1.51e+08     -0.805      0.421   -4.17e+08    1.74e+08
# continent[T.Asia]           3.385e+07   6.25e+07      0.541      0.588   -8.87e+07    1.56e+08
# continent[T.Europe]         1.099e+07   6.15e+07      0.179      0.858    -1.1e+08    1.32e+08
# continent[T.North_America]  2.638e+07   6.15e+07      0.429      0.668   -9.41e+07    1.47e+08
# continent[T.Oceania]        3.551e+07   6.32e+07      0.562      0.574   -8.83e+07    1.59e+08
# continent[T.South_America]  2.036e+07   7.52e+07      0.271      0.787   -1.27e+08    1.68e+08
# budget                         2.5002      0.056     44.886      0.000       2.391       2.609
# votes                        363.5786     11.814     30.776      0.000     340.418     386.739
# runtime                    -1.089e+05   1.16e+05     -0.936      0.349   -3.37e+05    1.19e+05
# score                       6.894e+06   2.23e+06      3.087      0.002    2.52e+06    1.13e+07
# year                        2.527e+05   1.72e+05      1.473      0.141   -8.36e+04    5.89e+05
# ==============================================================================
# Omnibus:                     3404.351   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250386.961
# Skew:                           3.176   Prob(JB):                         0.00
# Kurtosis:                      39.677   Cond. No.                     1.33e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# After looking at some of the p-values of the predictors, some visualizations should be made to understand these relationships better. The visualizations below are to look at predictors that are deemed insignificant or a portion of them are (such as genre - some genres are significant whiles others are not).

# %%
#YEAR
#although year doesn't seem to significant, 
#let's see if by binning it by decade will change anything

#Binning year
train_copy = train.copy()
binned_age = pd.qcut(train_copy['year'], 4,retbins=True, labels = ['80s', '90s', '00s', '10s'])
train_copy['year_binned'] = binned_age[0]

#creating an "outcome" col of whether gross was high (1) or low (0) based on the mean gross
mean_gross = train_copy['gross'].mean()

# Add column using np.where()
train_copy['outcome'] = np.where(train_copy['gross'] > mean_gross, 1, 0)

#Finding percentage of movies in each year bin
year_data = train_copy.groupby('year_binned')['outcome'].agg([('high_gross_percent','mean'),('nobs','count')]).reset_index(drop=False)

#Visualizing percentage 
sns.lineplot(x = year_data.index, y= year_data['high_gross_percent'])
plt.xlabel('year_bin')
plt.rcParams["figure.figsize"] = (7,4)

year_data
# Out:
#   year_binned  high_gross_percent  nobs
# 0         80s            0.090744  1102
# 1         90s            0.239819  1105
# 2         00s            0.324737  1047
# 3         10s            0.416436  1083

# %%
#Making dummy variables
dummy_year= pd.get_dummies(train_copy['year_binned'], drop_first = True) #ensures we just have 3 cols instead of 4
train_copy1 = pd.concat([train_copy, dummy_year], axis = 1)

ols_object1 = smf.ols(formula = 'gross~budget+genre+rating+votes+continent+runtime+score+year_binned', data = train_copy1)
model1 = ols_object1.fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     266.1
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        11:33:51   Log-Likelihood:                -86237.
# No. Observations:                4337   AIC:                         1.725e+05
# Df Residuals:                    4301   BIC:                         1.728e+05
# Df Model:                          35
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -3.247e+07   1.22e+08     -0.265      0.791   -2.72e+08    2.07e+08
# genre[T.Adventure]          1.045e+07   7.66e+06      1.364      0.173   -4.57e+06    2.55e+07
# genre[T.Animation]          6.745e+07      1e+07      6.748      0.000    4.79e+07     8.7e+07
# genre[T.Biography]         -5.019e+06   7.99e+06     -0.628      0.530   -2.07e+07    1.06e+07
# genre[T.Comedy]             1.962e+07   4.71e+06      4.162      0.000    1.04e+07    2.89e+07
# genre[T.Crime]              4.606e+06   7.03e+06      0.655      0.513   -9.18e+06    1.84e+07
# genre[T.Drama]              6.525e+06   5.57e+06      1.171      0.242    -4.4e+06    1.74e+07
# genre[T.Family]             4.717e+08   6.09e+07      7.746      0.000    3.52e+08    5.91e+08
# genre[T.Fantasy]             2.08e+07   1.99e+07      1.047      0.295   -1.81e+07    5.98e+07
# genre[T.Horror]             4.145e+07   8.36e+06      4.956      0.000    2.51e+07    5.79e+07
# genre[T.Mystery]            2.477e+07   3.06e+07      0.810      0.418   -3.52e+07    8.47e+07
# genre[T.Romance]            4.119e+06   5.28e+07      0.078      0.938   -9.94e+07    1.08e+08
# genre[T.Sci_Fi]            -3.134e+07    4.3e+07     -0.728      0.467   -1.16e+08     5.3e+07
# genre[T.Thriller]           3.221e+07   4.31e+07      0.748      0.455   -5.22e+07    1.17e+08
# genre[T.Western]           -1.242e+07   1.05e+08     -0.118      0.906   -2.19e+08    1.94e+08
# rating[T.G]                -4.846e+07   1.06e+08     -0.457      0.648   -2.57e+08     1.6e+08
# rating[T.NC_17]            -4.812e+07   1.11e+08     -0.435      0.664   -2.65e+08    1.69e+08
# rating[T.Not_Rated]        -3.552e+07   1.07e+08     -0.332      0.740   -2.45e+08    1.74e+08
# rating[T.PG]                -4.16e+07   1.05e+08     -0.395      0.693   -2.48e+08    1.65e+08
# rating[T.PG_13]            -4.777e+07   1.06e+08     -0.453      0.651   -2.55e+08    1.59e+08
# rating[T.R]                -6.275e+07   1.06e+08     -0.595      0.552    -2.7e+08    1.44e+08
# rating[T.TV_MA]            -8.323e+07   1.49e+08     -0.559      0.576   -3.75e+08    2.09e+08
# rating[T.Unrated]          -2.681e+07    1.1e+08     -0.244      0.807   -2.42e+08    1.89e+08
# rating[T.X]                 -1.13e+08   1.49e+08     -0.757      0.449   -4.06e+08     1.8e+08
# continent[T.Asia]           4.674e+07   6.18e+07      0.756      0.449   -7.44e+07    1.68e+08
# continent[T.Europe]         2.607e+07   6.09e+07      0.428      0.668   -9.32e+07    1.45e+08
# continent[T.North_America]  3.977e+07   6.08e+07      0.655      0.513   -7.94e+07    1.59e+08
# continent[T.Oceania]        4.739e+07   6.25e+07      0.759      0.448   -7.51e+07     1.7e+08
# continent[T.South_America]  4.089e+07   7.43e+07      0.550      0.582   -1.05e+08    1.87e+08
# year_binned[T.90s]         -2.773e+07   4.66e+06     -5.944      0.000   -3.69e+07   -1.86e+07
# year_binned[T.00s]         -3.169e+07   4.87e+06     -6.513      0.000   -4.12e+07   -2.22e+07
# year_binned[T.10s]          6.576e+06   4.94e+06      1.331      0.183   -3.11e+06    1.63e+07
# budget                         2.5514      0.055     46.345      0.000       2.443       2.659
# votes                        370.1827     11.724     31.576      0.000     347.198     393.167
# runtime                    -1.529e+05   1.15e+05     -1.329      0.184   -3.78e+05    7.27e+04
# score                       5.249e+06   2.21e+06      2.372      0.018    9.11e+05    9.59e+06
# ==============================================================================
# Omnibus:                     3334.663   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           243033.689
# Skew:                           3.073   Prob(JB):                         0.00
# Kurtosis:                      39.154   Cond. No.                     1.17e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Binning the year by decade seemed to help with only movies being made in the 2010s being deemed as insignifcant.

# %%
#GENRE
#some of the genres were significant, while others were not
sns.boxplot(x = 'genre', y = 'gross', data = train)
plt.rcParams["figure.figsize"] = (20,9)

# %%
#RATINGS
sns.boxplot(x = 'rating', y = 'gross', data = train)
plt.rcParams["figure.figsize"] = (20,9)

# %%
#from these box plots as well as the model, we can see that continent is not significant for continent
    #as there isn't much variation in the shape of the boxplots
sns.boxplot(x = 'continent', y = 'gross', data = train)
plt.rcParams["figure.figsize"] = (20,9)

# %% [markdown]
# ### TAKEAWAYS
# - year did not seem to be significant, however, after binning the movies by decade, we can see that it is significant for most decades (except for movies during 2010s).
# - runtime does not seem to be significant
# - only some of the genres seems to be significant - more evidence that they are signficant in backwards stepwise selection
# - rating does not seem to be signficant. After looking at the boxplots, they share similar shapes where lesser used ratings have a very small shape, PG and PG-13 seem to have the same shape, and only G-rated movies looks slightly larger.
# - contintent does not seem to be significant either. None of the p-values were below 0.05 and all of the boxplots seem to be pretty similar in shape.

# %% [markdown]
# ### LINEARITY ASSUMPTIONS (with model with no interactions/transformations)

# %%
#Plotting residuals vs fitted values
pred_gross = model.predict(test)
plt.rcParams["figure.figsize"] = (9,6)
sns.set(font_scale=1.25)
ax = sns.scatterplot(x = model.fittedvalues, y=model.resid,color = 'orange')
sns.lineplot(x = [pred_gross.min(),pred_gross.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
#trying it with the year_binned model

test_copy = test.copy()
binned_age = pd.qcut(test_copy['year'], 4,retbins=True, labels = ['80s', '90s', '00s', '10s'])
test_copy['year_binned'] = binned_age[0]

#creating an "outcome" col of whether gross was high (1) or low (0) based on the mean gross
mean_gross = test_copy['gross'].mean()

# Add column using np.where()
test_copy['outcome'] = np.where(test_copy['gross'] > mean_gross, 1, 0)

pred_gross = model1.predict(test_copy)
plt.rcParams["figure.figsize"] = (9,6)
sns.set(font_scale=1.25)
ax = sns.scatterplot(x = model1.fittedvalues, y=model1.resid,color = 'orange')
sns.lineplot(x = [pred_gross.min(),pred_gross.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')

#so it literally looks the same lol
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### MODEL WITH TRANSFORMATIONS/INTERACTIONS

# %%
# the start of a model by hand
ols_object = smf.ols(formula = 'gross~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)', data = train)
model = ols_object.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     607.3
# Date:                Wed, 01 Mar 2023   Prob (F-statistic):               0.00
# Time:                        23:06:09   Log-Likelihood:                -85915.
# No. Observations:                4337   AIC:                         1.719e+05
# Df Residuals:                    4317   BIC:                         1.720e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.0161      0.001     12.220      0.000       0.013       0.019
# genre[T.Adventure]            0.0182      0.001     12.203      0.000       0.015       0.021
# genre[T.Animation]           -0.0008   6.21e-05    -12.203      0.000      -0.001      -0.001
# genre[T.Biography]            0.0005      4e-05     12.237      0.000       0.000       0.001
# genre[T.Comedy]               0.0045      0.000     12.219      0.000       0.004       0.005
# genre[T.Crime]                0.0009   7.26e-05     12.224      0.000       0.001       0.001
# genre[T.Drama]                0.0031      0.000     12.226      0.000       0.003       0.004
# genre[T.Family]            1.151e-05   9.35e-07     12.305      0.000    9.68e-06    1.33e-05
# genre[T.Fantasy]              0.0004   3.23e-05     12.208      0.000       0.000       0.000
# genre[T.Horror]               0.0038      0.000     12.210      0.000       0.003       0.004
# genre[T.Mystery]          -4.698e-05   3.86e-06    -12.173      0.000   -5.45e-05   -3.94e-05
# genre[T.Romance]          -7.566e-06   6.31e-07    -11.994      0.000    -8.8e-06   -6.33e-06
# genre[T.Sci_Fi]            1.731e-05   1.42e-06     12.191      0.000    1.45e-05    2.01e-05
# genre[T.Thriller]          1.485e-05   1.22e-06     12.144      0.000    1.25e-05    1.73e-05
# genre[T.Western]          -5.486e-09   8.04e-07     -0.007      0.995   -1.58e-06    1.57e-06
# rating[T.G]                  -0.0008   6.48e-05    -12.203      0.000      -0.001      -0.001
# rating[T.NC_17]               0.0002   1.44e-05     12.213      0.000       0.000       0.000
# rating[T.Not_Rated]           0.0002   1.55e-05     12.223      0.000       0.000       0.000
# rating[T.PG]                 -0.0022      0.000    -12.203      0.000      -0.003      -0.002
# rating[T.PG_13]               0.0080      0.001     12.209      0.000       0.007       0.009
# rating[T.R]                   0.0107      0.001     12.223      0.000       0.009       0.012
# rating[T.TV_MA]            1.483e-06    1.2e-07     12.367      0.000    1.25e-06    1.72e-06
# rating[T.Unrated]          3.355e-05   2.75e-06     12.219      0.000    2.82e-05    3.89e-05
# rating[T.X]               -1.518e-05   1.24e-06    -12.196      0.000   -1.76e-05   -1.27e-05
# budget                        0.0206      0.101      0.203      0.839      -0.178       0.220
# budget:genre[T.Adventure]     0.4631      0.099      4.677      0.000       0.269       0.657
# budget:genre[T.Animation]     1.2829      0.082     15.670      0.000       1.122       1.443
# budget:genre[T.Biography]    -0.3942      0.194     -2.037      0.042      -0.774      -0.015
# budget:genre[T.Comedy]        0.2330      0.105      2.218      0.027       0.027       0.439
# budget:genre[T.Crime]        -0.3452      0.189     -1.826      0.068      -0.716       0.025
# budget:genre[T.Drama]         0.1909      0.129      1.486      0.137      -0.061       0.443
# budget:genre[T.Family]        5.3852      0.605      8.895      0.000       4.198       6.572
# budget:genre[T.Fantasy]      -0.6886      0.776     -0.887      0.375      -2.210       0.833
# budget:genre[T.Horror]        0.1007      0.346      0.291      0.771      -0.577       0.779
# budget:genre[T.Mystery]       0.3274      0.597      0.549      0.583      -0.842       1.497
# budget:genre[T.Romance]      -0.4946      2.621     -0.189      0.850      -5.634       4.645
# budget:genre[T.Sci_Fi]       -1.3860      1.109     -1.249      0.212      -3.561       0.789
# budget:genre[T.Thriller]      1.0231      2.854      0.358      0.720      -4.573       6.619
# budget:genre[T.Western]      -0.0598      8.844     -0.007      0.995     -17.398      17.278
# score                         0.0742      0.006     12.231      0.000       0.062       0.086
# votes                      1654.4497    135.110     12.245      0.000    1389.564    1919.335
# score:votes                -165.3905     17.284     -9.569      0.000    -199.276    -131.505
# I(budget ** 2)             1.052e-08   4.67e-10     22.514      0.000     9.6e-09    1.14e-08
# I(votes ** 2)                 0.0013      0.000      6.846      0.000       0.001       0.002
# I(score * votes ** 2)        -0.0001   2.17e-05     -6.851      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                     2921.120   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146066.654
# Skew:                           2.601   Prob(JB):                         0.00
# Kurtosis:                      30.951   Cond. No.                     6.93e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.93e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# RSE on training data
print(np.sqrt(model.mse_resid))
# RMSE
pred_gross = model.predict(test)
print(np.sqrt(((test.gross - (pred_gross))**2).mean()))
# Out:
# 106209867.05371588
# 117315833.09935851

# %%
# log of the model
ols_object = smf.ols(formula = 'np.log(gross)~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)', data = train)
model_log = ols_object.fit()
print(model_log.summary())

# RSE on training data
print(np.sqrt(model_log.mse_resid))
# RMSE
pred_log_gross = model_log.predict(test)
print(np.sqrt(((test.gross - np.exp(pred_log_gross))**2).mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(gross)   R-squared:                     -19.061
# Model:                            OLS   Adj. R-squared:                -19.149
# Method:                 Least Squares   F-statistic:                    -215.9
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               1.00
# Time:                        11:47:37   Log-Likelihood:                -15389.
# No. Observations:                4337   AIC:                         3.082e+04
# Df Residuals:                    4317   BIC:                         3.094e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  1.777e-09   1.14e-10     15.607      0.000    1.55e-09       2e-09
# genre[T.Adventure]         2.015e-09   1.29e-10     15.588      0.000    1.76e-09    2.27e-09
# genre[T.Animation]        -8.385e-11   5.38e-12    -15.574      0.000   -9.44e-11   -7.33e-11
# genre[T.Biography]         5.427e-11   3.47e-12     15.643      0.000    4.75e-11    6.11e-11
# genre[T.Comedy]            4.934e-10   3.16e-11     15.606      0.000    4.31e-10    5.55e-10
# genre[T.Crime]             9.827e-11   6.29e-12     15.615      0.000    8.59e-11    1.11e-10
# genre[T.Drama]             3.485e-10   2.23e-11     15.619      0.000    3.05e-10    3.92e-10
# genre[T.Family]            1.272e-12   8.11e-14     15.696      0.000    1.11e-12    1.43e-12
# genre[T.Fantasy]           4.356e-11    2.8e-12     15.584      0.000    3.81e-11     4.9e-11
# genre[T.Horror]            4.176e-10   2.68e-11     15.586      0.000    3.65e-10     4.7e-10
# genre[T.Mystery]          -5.187e-12   3.34e-13    -15.512      0.000   -5.84e-12   -4.53e-12
# genre[T.Romance]          -8.126e-13   5.47e-14    -14.867      0.000    -9.2e-13   -7.05e-13
# genre[T.Sci_Fi]            1.918e-12   1.23e-13     15.591      0.000    1.68e-12    2.16e-12
# genre[T.Thriller]          1.669e-12   1.06e-13     15.749      0.000    1.46e-12    1.88e-12
# genre[T.Western]           9.354e-14   6.97e-14      1.343      0.179    -4.3e-14     2.3e-13
# rating[T.G]                -8.74e-11   5.61e-12    -15.572      0.000   -9.84e-11   -7.64e-11
# rating[T.NC_17]            1.943e-11   1.25e-12     15.593      0.000     1.7e-11    2.19e-11
# rating[T.Not_Rated]        2.101e-11   1.35e-12     15.614      0.000    1.84e-11    2.36e-11
# rating[T.PG]              -2.481e-10   1.59e-11    -15.565      0.000   -2.79e-10   -2.17e-10
# rating[T.PG_13]            8.882e-10    5.7e-11     15.584      0.000    7.77e-10       1e-09
# rating[T.R]                1.182e-09   7.57e-11     15.613      0.000    1.03e-09    1.33e-09
# rating[T.TV_MA]            1.653e-13   1.04e-14     15.911      0.000    1.45e-13    1.86e-13
# rating[T.Unrated]          3.712e-12   2.38e-13     15.605      0.000    3.25e-12    4.18e-12
# rating[T.X]               -1.677e-12   1.08e-13    -15.556      0.000   -1.89e-12   -1.47e-12
# budget                     2.784e-07   8.79e-09     31.667      0.000    2.61e-07    2.96e-07
# budget:genre[T.Adventure]  1.793e-09   8.58e-09      0.209      0.834    -1.5e-08    1.86e-08
# budget:genre[T.Animation] -1.472e-08   7.09e-09     -2.075      0.038   -2.86e-08   -8.12e-10
# budget:genre[T.Biography]  5.492e-08   1.68e-08      3.275      0.001     2.2e-08    8.78e-08
# budget:genre[T.Comedy]     8.358e-08    9.1e-09      9.183      0.000    6.57e-08    1.01e-07
# budget:genre[T.Crime]      5.979e-08   1.64e-08      3.650      0.000    2.77e-08    9.19e-08
# budget:genre[T.Drama]      7.522e-08   1.11e-08      6.756      0.000    5.34e-08     9.7e-08
# budget:genre[T.Family]    -3.236e-08   5.25e-08     -0.617      0.537   -1.35e-07    7.05e-08
# budget:genre[T.Fantasy]    8.927e-08   6.72e-08      1.328      0.184   -4.25e-08    2.21e-07
# budget:genre[T.Horror]     1.511e-07      3e-08      5.043      0.000    9.24e-08     2.1e-07
# budget:genre[T.Mystery]     2.63e-08   5.17e-08      0.509      0.611    -7.5e-08    1.28e-07
# budget:genre[T.Romance]    4.215e-07   2.27e-07      1.856      0.064   -2.38e-08    8.67e-07
# budget:genre[T.Sci_Fi]      2.33e-08   9.61e-08      0.242      0.809   -1.65e-07    2.12e-07
# budget:genre[T.Thriller]   5.526e-07   2.47e-07      2.234      0.026    6.77e-08    1.04e-06
# budget:genre[T.Western]    1.029e-06   7.66e-07      1.343      0.179   -4.73e-07    2.53e-06
# score                      8.218e-09   5.26e-10     15.632      0.000    7.19e-09    9.25e-09
# votes                         0.0002   1.17e-05     15.659      0.000       0.000       0.000
# score:votes               -1.538e-05    1.5e-06    -10.268      0.000   -1.83e-05   -1.24e-05
# I(budget ** 2)            -1.174e-15   4.05e-17    -29.011      0.000   -1.25e-15   -1.09e-15
# I(votes ** 2)             -4.067e-10   1.71e-11    -23.854      0.000    -4.4e-10   -3.73e-10
# I(score * votes ** 2)       4.31e-11   1.88e-12     22.969      0.000    3.94e-11    4.68e-11
# ==============================================================================
# Omnibus:                      406.936   Durbin-Watson:                   1.436
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              872.030
# Skew:                          -0.594   Prob(JB):                    4.38e-190
# Kurtosis:                       4.848   Cond. No.                     6.93e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.93e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 8.428178192133123
# 6.363262159093935e+17

# %%
#using year_binned - doesn't change R^2 at all and RSE/RMSE is worse than the model above
#so using year_binned isn't actually helpful for us

ols_object = smf.ols(formula = 'gross~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)+year_binned', data = train_copy)
model2 = ols_object.fit()
print(model2.summary())

# RSE on training data
print(np.sqrt(model1.mse_resid))
# RMSE
pred_gross = model1.predict(test_copy)
print(np.sqrt(((test_copy.gross - (pred_gross))**2).mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     607.3
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        11:48:44   Log-Likelihood:                -85915.
# No. Observations:                4337   AIC:                         1.719e+05
# Df Residuals:                    4317   BIC:                         1.720e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.0161      0.001     12.220      0.000       0.013       0.019
# genre[T.Adventure]           -0.0202      0.002    -12.172      0.000      -0.024      -0.017
# genre[T.Animation]           -0.0007   6.08e-05    -12.203      0.000      -0.001      -0.001
# genre[T.Biography]            0.0005   3.97e-05     12.237      0.000       0.000       0.001
# genre[T.Comedy]               0.0045      0.000     12.219      0.000       0.004       0.005
# genre[T.Crime]                0.0009   7.26e-05     12.224      0.000       0.001       0.001
# genre[T.Drama]                0.0031      0.000     12.226      0.000       0.003       0.004
# genre[T.Family]            1.151e-05   9.35e-07     12.305      0.000    9.67e-06    1.33e-05
# genre[T.Fantasy]              0.0004   3.23e-05     12.208      0.000       0.000       0.000
# genre[T.Horror]               0.0038      0.000     12.210      0.000       0.003       0.004
# genre[T.Mystery]          -4.698e-05   3.86e-06    -12.173      0.000   -5.45e-05   -3.94e-05
# genre[T.Romance]           -7.56e-06    6.3e-07    -11.993      0.000    -8.8e-06   -6.32e-06
# genre[T.Sci_Fi]            1.731e-05   1.42e-06     12.191      0.000    1.45e-05    2.01e-05
# genre[T.Thriller]          1.484e-05   1.22e-06     12.144      0.000    1.24e-05    1.72e-05
# genre[T.Western]           1.082e-08   8.04e-07      0.013      0.989   -1.57e-06    1.59e-06
# rating[T.G]                  -0.0008   6.48e-05    -12.203      0.000      -0.001      -0.001
# rating[T.NC_17]               0.0002   1.43e-05     12.213      0.000       0.000       0.000
# rating[T.Not_Rated]           0.0002   1.55e-05     12.223      0.000       0.000       0.000
# rating[T.PG]                 -0.0022      0.000    -12.203      0.000      -0.003      -0.002
# rating[T.PG_13]               0.0080      0.001     12.209      0.000       0.007       0.009
# rating[T.R]                   0.0107      0.001     12.223      0.000       0.009       0.012
# rating[T.TV_MA]            1.483e-06    1.2e-07     12.367      0.000    1.25e-06    1.72e-06
# rating[T.Unrated]          3.355e-05   2.75e-06     12.219      0.000    2.82e-05    3.89e-05
# rating[T.X]               -1.518e-05   1.24e-06    -12.196      0.000   -1.76e-05   -1.27e-05
# year_binned[T.90s]           -0.0053      0.000    -12.203      0.000      -0.006      -0.004
# year_binned[T.00s]            0.0132      0.001     12.210      0.000       0.011       0.015
# year_binned[T.10s]            0.0120      0.001     12.213      0.000       0.010       0.014
# budget                        0.0206      0.101      0.203      0.839      -0.178       0.220
# budget:genre[T.Adventure]     0.4631      0.099      4.677      0.000       0.269       0.657
# budget:genre[T.Animation]     1.2829      0.082     15.670      0.000       1.122       1.443
# budget:genre[T.Biography]    -0.3942      0.194     -2.037      0.042      -0.774      -0.015
# budget:genre[T.Comedy]        0.2330      0.105      2.218      0.027       0.027       0.439
# budget:genre[T.Crime]        -0.3452      0.189     -1.826      0.068      -0.716       0.025
# budget:genre[T.Drama]         0.1909      0.129      1.486      0.137      -0.061       0.443
# budget:genre[T.Family]        5.3852      0.605      8.895      0.000       4.198       6.572
# budget:genre[T.Fantasy]      -0.6886      0.776     -0.887      0.375      -2.210       0.833
# budget:genre[T.Horror]        0.1007      0.346      0.291      0.771      -0.577       0.779
# budget:genre[T.Mystery]       0.3274      0.597      0.549      0.583      -0.842       1.497
# budget:genre[T.Romance]      -0.4946      2.621     -0.189      0.850      -5.634       4.645
# budget:genre[T.Sci_Fi]       -1.3860      1.109     -1.249      0.212      -3.561       0.789
# budget:genre[T.Thriller]      1.0231      2.854      0.358      0.720      -4.573       6.619
# budget:genre[T.Western]      -0.0598      8.844     -0.007      0.995     -17.398      17.278
# score                         0.0742      0.006     12.231      0.000       0.062       0.086
# votes                      1654.4497    135.110     12.245      0.000    1389.564    1919.335
# score:votes                -165.3905     17.284     -9.569      0.000    -199.276    -131.505
# I(budget ** 2)             1.052e-08   4.67e-10     22.514      0.000     9.6e-09    1.14e-08
# I(votes ** 2)                 0.0013      0.000      6.846      0.000       0.001       0.002
# I(score * votes ** 2)        -0.0001   2.17e-05     -6.851      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                     2921.120   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146066.654
# Skew:                           2.601   Prob(JB):                         0.00
# Kurtosis:                      30.951   Cond. No.                     6.95e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.95e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 104982185.37574151
# 116203938.73408803

# %% [markdown]
# ### LINEARITY ASSUMPTIONS (with model with interactions/transformations)

# %%
#Plotting residuals vs fitted values
pred_gross = model.predict(test)
plt.rcParams["figure.figsize"] = (9,6)
sns.set(font_scale=1.25)
ax = sns.scatterplot(x = model.fittedvalues, y=model.resid,color = 'orange')
sns.lineplot(x = [pred_gross.min(),pred_gross.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# log model
sns.scatterplot(x = (model_log.fittedvalues), y=(model_log.resid),color = 'orange')
sns.lineplot(x = [model_log.fittedvalues.min(),model_log.fittedvalues.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### Visualizations to help make the model:

# %%
cols = ['rating','genre','year','score','votes','budget','continent','runtime']
for col in cols:
    plt.rcParams["figure.figsize"] = (7,4)
    sns.set(font_scale=1.25)
    sns.scatterplot(x = col, y = 'gross', data = train)
    plt.show()

# %%
cols = ['year','score','votes','runtime']
for col in cols:
    plt.rcParams["figure.figsize"] = (7,4)
    sns.set(font_scale=1.25)
    sns.scatterplot(x = col, y = 'budget', data = train)
    plt.show()

# %%
cols = ['year','score']
for col in cols:
    plt.rcParams["figure.figsize"] = (7,4)
    sns.set(font_scale=1.25)
    sns.scatterplot(x = col, y = 'votes', data = train)
    plt.show()

# %%
cols = ['year']
for col in cols:
    plt.rcParams["figure.figsize"] = (7,4)
    sns.set(font_scale=1.25)
    sns.scatterplot(x = col, y = 'score', data = train)
    plt.show()

# %%
# visualizations of categorical variables vs gross
for col in ['rating','genre','continent']:
    sns.boxplot(x = col, y = np.log(train.gross), data = train)
    plt.show()

# %%
# visualizations of categorical variables vs gross
for col in ['rating','genre','continent']:
    sns.boxplot(x = col, y = np.log(train.budget), data = train)
    plt.show()

# %%
# visualizations of categorical variables vs gross
for col in ['rating','genre','continent']:
    sns.boxplot(x = col, y = np.log(train.runtime), data = train)
    plt.show()

# %%
# visualizations of categorical variables vs gross
for col in ['rating','genre','continent']:
    sns.boxplot(x = col, y = np.log(train.votes), data = train)
    plt.show()

# %%
# visualizations of categorical variables vs gross
for col in ['rating','genre','continent']:
    sns.boxplot(x = col, y = np.log(train.score), data = train)
    plt.show()

# %%
train.corrwith(train.gross).sort_values(ascending = False)
# Out:
# gross         1.000000
# budget        0.744515
# votes         0.622671
# year          0.274300
# runtime       0.272977
# Unnamed: 0    0.265950
# index         0.264100
# score         0.225487
# dtype: float64

# %%
train.corrwith(train.budget).sort_values(ascending = False)
# Out:
# budget        1.000000
# gross         0.744515
# votes         0.451332
# year          0.327472
# runtime       0.319605
# index         0.318929
# Unnamed: 0    0.314499
# score         0.070302
# dtype: float64

# %%
train.corrwith(train.votes).sort_values(ascending = False)
# Out:
# votes         1.000000
# gross         0.622671
# score         0.475330
# budget        0.451332
# runtime       0.354981
# year          0.210504
# index         0.197007
# Unnamed: 0    0.195359
# dtype: float64

# %% [markdown]
# ## MULTICOLLINEARITY CHECK

# %%
# doing VIF to see if there is multicollinearity
X = train[['year','score','votes','budget','runtime']]
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#    feature           VIF
# 0    const  40965.310821
# 1     year      1.130068
# 2    score      1.512960
# 3    votes      1.685885
# 4   budget      1.499190
# 5  runtime      1.347823

# %% [markdown]
# There is very little collinearity! All values are below 5/10.

# %%
sns.set(rc={'figure.figsize':(12,10)})
sns.heatmap(train.corr())
plt.xlabel('Predictors', fontsize=20)
plt.ylabel('Predictors',fontsize=20)
plt.title('Heatmap of Predictors', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Heatmap of Predictors')

# %%
def dummies_for_countries(df):
    rating_dummy = pd.get_dummies(df['rating'])
    df = pd.concat([df, rating_dummy], axis=1)
    df = df.drop('rating', axis=1)
    genre_dummy = pd.get_dummies(df['genre'])
    df = pd.concat([df, genre_dummy], axis=1)
    df = df.drop('genre', axis=1)
    country_dummy = pd.get_dummies(df['country'])
    df = pd.concat([df, country_dummy], axis=1)
    df = df.drop('country', axis=1)
    return df

train = dummies_for_countries(train)
test = dummies_for_countries(test)

# %%
#Creating a set of predictors from which we need to find the best subset of predictors
X = train[['year','score','votes','budget','runtime','United_States', 'United_Kingdom', 'France', 'Germany', 'Belgium',
       'Spain', 'Japan', 'Australia', 'New_Zealand', 'China', 'Canada',
       'Austria', 'Norway', 'Iceland', 'West_Germany', 'Mexico',
       'Ireland', 'Italy', 'South_Korea', 'Hong_Kong', 'India',
       'United_Arab_Emirates', 'Czech_Republic', 'Finland', 'Taiwan',
       'Lebanon', 'South_Africa', 'Argentina', 'Indonesia', 'Iran',
       'Switzerland', 'Brazil', 'Republic_of_Macedonia', 'Sweden',
       'Russia', 'Netherlands', 'Aruba', 'Jamaica', 'Chile', 'Panama',
       'Denmark', 'Israel', 'Federal_Republic_of_Yugoslavia', 'Kenya',
       'Yugoslavia', 'Hungary','Comedy', 'Action', 'Drama', 'Biography', 'Horror', 'Adventure',
       'Crime', 'Animation', 'Fantasy', 'Thriller', 'Mystery', 'Sci_Fi',
       'Family', 'Romance', 'Western','PG_13', 'R', 'PG', 'Not_Rated', 'G', 'Unrated', 'X', 'NC_17',
       'Approved', 'TV_MA']]

# %%
#Function to develop a model based on all predictors in predictor_subset
def processSubset(predictor_subset):
    # Fit model on feature_set and calculate R-squared
    model = smf.ols('gross~' + '+'.join(predictor_subset),data = train).fit()
    Rsquared = model.rsquared
    return {"model":model, "Rsquared":Rsquared}

# %%
#Function to select the best model amongst all models with 'k' predictors
def getBest_model(k):
    tic = time.time()
    results = []
    for combo in itertools.combinations(X.columns, k):
        results.append(processSubset((list(combo))))

    # Wrap everything up in a dataframe
    models = pd.DataFrame(results)

    # Choose the model with the highest RSS
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed", models.shape[0], "models on", k, "predictors in", (toc-tic), "seconds.")
    return best_model

# %%
def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    # Set up a 2x2 grid so we can look at 4 plots at once
    plt.subplot(2, 2, 1)

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector
    plt.plot(models_best["Rsquared"])
    plt.xlabel('# Predictors')
    plt.ylabel('Rsquared')

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector

    rsquared_adj = models_best.apply(lambda row: row[1].rsquared_adj, axis=1)

    plt.subplot(2, 2, 2)
    plt.plot(rsquared_adj)
    plt.plot(1+rsquared_adj.argmax(), rsquared_adj.max(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('adjusted rsquared')

    # We'll do the same for AIC and BIC, this time looking for the models with the SMALLEST statistic
    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 3)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 4)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')

# %% [markdown]
# ## FORWARD STEPWISE SELECTION using COUNTRYs (scroll to bottom for continents)

# %%
#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors we still need to process
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    tic = time.time()
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

# %%
def forward_selection():
    models_best = pd.DataFrame(columns=["Rsquared", "model"])

    tic = time.time()
    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

# %%
models_best = forward_selection()
# Out:
# Processed  76 models on 1 predictors in 0.36116981506347656 seconds.
# Processed  75 models on 2 predictors in 0.45697784423828125 seconds.
# Processed  74 models on 3 predictors in 0.558610200881958 seconds.
# Processed  73 models on 4 predictors in 0.6406266689300537 seconds.
# Processed  72 models on 5 predictors in 0.6319777965545654 seconds.
# Processed  71 models on 6 predictors in 0.7751471996307373 seconds.
# Processed  70 models on 7 predictors in 0.9065995216369629 seconds.
# Processed  69 models on 8 predictors in 0.8836357593536377 seconds.
# Processed  68 models on 9 predictors in 0.9169042110443115 seconds.
# Processed  67 models on 10 predictors in 1.0863749980926514 seconds.
# Processed  66 models on 11 predictors in 1.0981287956237793 seconds.
# Processed  65 models on 12 predictors in 1.1472172737121582 seconds.
# Processed  64 models on 13 predictors in 1.2605252265930176 seconds.
# Processed  63 models on 14 predictors in 1.3644368648529053 seconds.
# Processed  62 models on 15 predictors in 1.9559171199798584 seconds.
# Processed  61 models on 16 predictors in 2.103024959564209 seconds.
# Processed  60 models on 17 predictors in 1.9319500923156738 seconds.
# Processed  59 models on 18 predictors in 2.09895920753479 seconds.
# Processed  58 models on 19 predictors in 2.0633606910705566 seconds.
# Processed  57 models on 20 predictors in 2.168613910675049 seconds.
# Processed  56 models on 21 predictors in 2.2884106636047363 seconds.
# Processed  55 models on 22 predictors in 2.5720860958099365 seconds.
# Processed  54 models on 23 predictors in 2.617234230041504 seconds.
# Processed  53 models on 24 predictors in 2.4782235622406006 seconds.
# Processed  52 models on 25 predictors in 2.333195209503174 seconds.
# Processed  51 models on 26 predictors in 2.472874402999878 seconds.
# Processed  50 models on 27 predictors in 2.61854887008667 seconds.
# Processed  49 models on 28 predictors in 3.445030450820923 seconds.
# Processed  48 models on 29 predictors in 3.1398918628692627 seconds.
# Processed  47 models on 30 predictors in 3.1674933433532715 seconds.
# Processed  46 models on 31 predictors in 4.612373352050781 seconds.
# Processed  45 models on 32 predictors in 3.6492762565612793 seconds.
# Processed  44 models on 33 predictors in 5.441166162490845 seconds.
# Processed  43 models on 34 predictors in 3.5925352573394775 seconds.
# Processed  42 models on 35 predictors in 3.21951961517334 seconds.
# Processed  41 models on 36 predictors in 2.767052412033081 seconds.
# Processed  40 models on 37 predictors in 4.345869541168213 seconds.
# Processed  39 models on 38 predictors in 3.628601312637329 seconds.
# Processed  38 models on 39 predictors in 2.795743703842163 seconds.
# Processed  37 models on 40 predictors in 2.7380850315093994 seconds.
# Processed  36 models on 41 predictors in 2.848590850830078 seconds.
# Processed  35 models on 42 predictors in 3.342872381210327 seconds.
# Processed  34 models on 43 predictors in 3.3095316886901855 seconds.
# Processed  33 models on 44 predictors in 3.4603383541107178 seconds.
# Processed  32 models on 45 predictors in 2.570011854171753 seconds.
# Processed  31 models on 46 predictors in 2.8211700916290283 seconds.
# Processed  30 models on 47 predictors in 4.079822063446045 seconds.
# Processed  29 models on 48 predictors in 3.3590924739837646 seconds.
# Processed  28 models on 49 predictors in 3.1360788345336914 seconds.
# Processed  27 models on 50 predictors in 2.696147918701172 seconds.
# Processed  26 models on 51 predictors in 2.9137563705444336 seconds.
# Processed  25 models on 52 predictors in 3.5027637481689453 seconds.
# Processed  24 models on 53 predictors in 2.47326922416687 seconds.
# Processed  23 models on 54 predictors in 2.6645641326904297 seconds.
# Processed  22 models on 55 predictors in 2.257432460784912 seconds.
# Processed  21 models on 56 predictors in 2.4742228984832764 seconds.
# Processed  20 models on 57 predictors in 2.231194019317627 seconds.
# Processed  19 models on 58 predictors in 2.8724730014801025 seconds.
# Processed  18 models on 59 predictors in 2.49906063079834 seconds.
# Processed  17 models on 60 predictors in 1.9168424606323242 seconds.
# Processed  16 models on 61 predictors in 1.7333014011383057 seconds.
# Processed  15 models on 62 predictors in 1.856290578842163 seconds.
# Processed  14 models on 63 predictors in 1.7490861415863037 seconds.
# Processed  13 models on 64 predictors in 1.543945550918579 seconds.
# Processed  12 models on 65 predictors in 1.473998785018921 seconds.
# Processed  11 models on 66 predictors in 1.5196707248687744 seconds.
# Processed  10 models on 67 predictors in 1.6555910110473633 seconds.
# Processed  9 models on 68 predictors in 1.2306177616119385 seconds.
# Processed  8 models on 69 predictors in 1.0342323780059814 seconds.
# Processed  7 models on 70 predictors in 0.9093115329742432 seconds.
# Processed  6 models on 71 predictors in 0.7856266498565674 seconds.
# Processed  5 models on 72 predictors in 0.6627762317657471 seconds.
# Processed  4 models on 73 predictors in 0.5573508739471436 seconds.
# Processed  3 models on 74 predictors in 0.4181947708129883 seconds.
# Processed  2 models on 75 predictors in 0.27533912658691406 seconds.
# Processed  1 models on 76 predictors in 0.1406245231628418 seconds.
# Total elapsed time: 164.42457222938538 seconds.

# %%
best_sub_plots()

# %%
best_fwd_reg_model1 = models_best['model'][9]
best_fwd_reg_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.675
# Method:                 Least Squares   F-statistic:                     999.9
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:01:14   Log-Likelihood:                -86296.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4327   BIC:                         1.727e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -3.072e+07   3.46e+06     -8.871      0.000   -3.75e+07   -2.39e+07
# budget          2.4814      0.047     52.731      0.000       2.389       2.574
# votes         377.1799     10.068     37.462      0.000     357.441     396.919
# Animation    7.328e+07   7.71e+06      9.505      0.000    5.82e+07    8.84e+07
# Family       4.812e+08   6.13e+07      7.846      0.000    3.61e+08    6.01e+08
# R           -1.712e+07   3.48e+06     -4.915      0.000   -2.39e+07   -1.03e+07
# Horror        3.76e+07   7.84e+06      4.793      0.000    2.22e+07     5.3e+07
# Comedy        1.42e+07   3.77e+06      3.765      0.000    6.81e+06    2.16e+07
# Germany     -3.915e+07   1.25e+07     -3.121      0.002   -6.37e+07   -1.46e+07
# New_Zealand   7.27e+07    2.6e+07      2.801      0.005    2.18e+07    1.24e+08
# ==============================================================================
# Omnibus:                     3398.856   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250024.892
# Skew:                           3.168   Prob(JB):                         0.00
# Kurtosis:                      39.653   Cond. No.                     2.09e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
best_fwd_reg_model2 = models_best['model'][8]
best_fwd_reg_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     1122.
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:01:36   Log-Likelihood:                -86300.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4328   BIC:                         1.727e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.065e+07   3.47e+06     -8.844      0.000   -3.74e+07   -2.39e+07
# budget         2.4806      0.047     52.674      0.000       2.388       2.573
# votes        380.0473     10.024     37.914      0.000     360.395     399.699
# Animation   7.282e+07   7.71e+06      9.440      0.000    5.77e+07    8.79e+07
# Family      4.805e+08   6.14e+07      7.829      0.000     3.6e+08    6.01e+08
# R          -1.719e+07   3.49e+06     -4.932      0.000    -2.4e+07   -1.04e+07
# Horror      3.737e+07   7.85e+06      4.761      0.000     2.2e+07    5.28e+07
# Comedy      1.416e+07   3.78e+06      3.751      0.000    6.76e+06    2.16e+07
# Germany    -3.947e+07   1.26e+07     -3.144      0.002   -6.41e+07   -1.49e+07
# ==============================================================================
# Omnibus:                     3374.784   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           246036.408
# Skew:                           3.134   Prob(JB):                         0.00
# Kurtosis:                      39.362   Cond. No.                     2.09e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Finding the RMSE of the model selected using the forward selection procedure, where the predictors
#include 2-factor interactions
pred_gross = best_fwd_reg_model1.predict(test)
np.sqrt(((pred_gross - test.gross)**2).mean())
# Out:
# 117156846.16279814

# %% [markdown]
# ## BACKWARDS STEPWISE SELECTION using COUNTRYs (scroll to bottom for continents)

# %%
def backward(predictors):
    
    tic = time.time()
    
    results = []
    
    for combo in itertools.combinations(predictors, len(predictors)-1):
        results.append(processSubset(combo))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)-1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

# %%
def backward_selection():
    models_best = pd.DataFrame(columns=["Rsquared", "model"], index = range(1,len(X.columns)))

    tic = time.time()
    predictors = X.columns
    models_best.loc[len(predictors)] = processSubset(predictors)
    
    while(len(predictors) > 1):  
        models_best.loc[len(predictors)-1] = backward(predictors)
        predictors = models_best.loc[len(predictors)-1]["model"].params.index[1:]

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

# %%
models_best = backward_selection()
# Out:
# Processed  76 models on 75 predictors in 8.397974491119385 seconds.
# Processed  75 models on 74 predictors in 11.03015685081482 seconds.
# Processed  74 models on 73 predictors in 11.429473876953125 seconds.
# Processed  73 models on 72 predictors in 10.98466968536377 seconds.
# Processed  72 models on 71 predictors in 11.571916818618774 seconds.
# Processed  71 models on 70 predictors in 10.818240880966187 seconds.
# Processed  70 models on 69 predictors in 9.906386137008667 seconds.
# Processed  69 models on 68 predictors in 11.121134757995605 seconds.
# Processed  68 models on 67 predictors in 10.717648983001709 seconds.
# Processed  67 models on 66 predictors in 8.804536581039429 seconds.
# Processed  66 models on 65 predictors in 9.45012617111206 seconds.
# Processed  65 models on 64 predictors in 8.860215902328491 seconds.
# Processed  64 models on 63 predictors in 9.134435176849365 seconds.
# Processed  63 models on 62 predictors in 8.529803037643433 seconds.
# Processed  62 models on 61 predictors in 8.217533349990845 seconds.
# Processed  61 models on 60 predictors in 8.593151092529297 seconds.
# Processed  60 models on 59 predictors in 7.165194272994995 seconds.
# Processed  59 models on 58 predictors in 6.842816114425659 seconds.
# Processed  58 models on 57 predictors in 6.463252305984497 seconds.
# Processed  57 models on 56 predictors in 6.061697483062744 seconds.
# Processed  56 models on 55 predictors in 6.367005109786987 seconds.
# Processed  55 models on 54 predictors in 5.644586563110352 seconds.
# Processed  54 models on 53 predictors in 5.739764928817749 seconds.
# Processed  53 models on 52 predictors in 6.65024995803833 seconds.
# Processed  52 models on 51 predictors in 5.38250207901001 seconds.
# Processed  51 models on 50 predictors in 5.327166795730591 seconds.
# Processed  50 models on 49 predictors in 4.769371032714844 seconds.
# Processed  49 models on 48 predictors in 4.239805698394775 seconds.
# Processed  48 models on 47 predictors in 4.2272374629974365 seconds.
# Processed  47 models on 46 predictors in 4.6572675704956055 seconds.
# Processed  46 models on 45 predictors in 3.784531354904175 seconds.
# Processed  45 models on 44 predictors in 3.8478076457977295 seconds.
# Processed  44 models on 43 predictors in 3.4983174800872803 seconds.
# Processed  43 models on 42 predictors in 4.0258848667144775 seconds.
# Processed  42 models on 41 predictors in 3.223222494125366 seconds.
# Processed  41 models on 40 predictors in 3.036940097808838 seconds.
# Processed  40 models on 39 predictors in 3.119126319885254 seconds.
# Processed  39 models on 38 predictors in 2.7934956550598145 seconds.
# Processed  38 models on 37 predictors in 3.104485273361206 seconds.
# Processed  37 models on 36 predictors in 2.551414966583252 seconds.
# Processed  36 models on 35 predictors in 2.5307037830352783 seconds.
# Processed  35 models on 34 predictors in 2.2860257625579834 seconds.
# Processed  34 models on 33 predictors in 2.0857884883880615 seconds.
# Processed  33 models on 32 predictors in 2.445327043533325 seconds.
# Processed  32 models on 31 predictors in 2.655789375305176 seconds.
# Processed  31 models on 30 predictors in 2.180269718170166 seconds.
# Processed  30 models on 29 predictors in 1.680206060409546 seconds.
# Processed  29 models on 28 predictors in 1.5157432556152344 seconds.
# Processed  28 models on 27 predictors in 1.4453275203704834 seconds.
# Processed  27 models on 26 predictors in 1.377208948135376 seconds.
# Processed  26 models on 25 predictors in 1.2366821765899658 seconds.
# Processed  25 models on 24 predictors in 1.1692464351654053 seconds.
# Processed  24 models on 23 predictors in 1.1538586616516113 seconds.
# Processed  23 models on 22 predictors in 0.9756059646606445 seconds.
# Processed  22 models on 21 predictors in 0.8825943470001221 seconds.
# Processed  21 models on 20 predictors in 0.8459358215332031 seconds.
# Processed  20 models on 19 predictors in 0.9228262901306152 seconds.
# Processed  19 models on 18 predictors in 0.7960100173950195 seconds.
# Processed  18 models on 17 predictors in 0.7778835296630859 seconds.
# Processed  17 models on 16 predictors in 0.6769111156463623 seconds.
# Processed  16 models on 15 predictors in 0.49927210807800293 seconds.
# Processed  15 models on 14 predictors in 0.4686918258666992 seconds.
# Processed  14 models on 13 predictors in 0.3732337951660156 seconds.
# Processed  13 models on 12 predictors in 0.33362483978271484 seconds.
# Processed  12 models on 11 predictors in 0.28150486946105957 seconds.
# Processed  11 models on 10 predictors in 0.2574625015258789 seconds.
# Processed  10 models on 9 predictors in 0.1635746955871582 seconds.
# Processed  9 models on 8 predictors in 0.16452407836914062 seconds.
# Processed  8 models on 7 predictors in 0.14071893692016602 seconds.
# Processed  7 models on 6 predictors in 0.10710334777832031 seconds.
# Processed  6 models on 5 predictors in 0.06619453430175781 seconds.
# Processed  5 models on 4 predictors in 0.046859025955200195 seconds.
# Processed  4 models on 3 predictors in 0.046865224838256836 seconds.
# Processed  3 models on 2 predictors in 0.0268557071685791 seconds.
# Processed  2 models on 1 predictors in 0.024147748947143555 seconds.
# Total elapsed time: 304.5760078430176 seconds.

# %%
best_sub_plots()

# %%
best_bwd_reg_model3 = models_best['model'][19]
best_bwd_reg_model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     472.4
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):               0.00
# Time:                        22:57:17   Log-Likelihood:                -86297.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4317   BIC:                         1.728e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.275e+08   6.16e+07      6.939      0.000    3.07e+08    5.48e+08
# votes        381.1975     10.065     37.872      0.000     361.464     400.931
# budget         2.4898      0.050     49.774      0.000       2.392       2.588
# Germany    -4.003e+07   1.26e+07     -3.185      0.001   -6.47e+07   -1.54e+07
# Comedy     -4.604e+08   6.16e+07     -7.477      0.000   -5.81e+08    -3.4e+08
# Action     -4.763e+08   6.16e+07     -7.735      0.000   -5.97e+08   -3.56e+08
# Drama      -4.713e+08   6.17e+07     -7.644      0.000   -5.92e+08    -3.5e+08
# Biography  -4.818e+08   6.19e+07     -7.788      0.000   -6.03e+08   -3.61e+08
# Horror      -4.37e+08    6.2e+07     -7.047      0.000   -5.59e+08   -3.15e+08
# Adventure  -4.687e+08   6.18e+07     -7.591      0.000    -5.9e+08   -3.48e+08
# Crime      -4.771e+08   6.18e+07     -7.716      0.000   -5.98e+08   -3.56e+08
# Animation  -4.007e+08   6.18e+07     -6.484      0.000   -5.22e+08    -2.8e+08
# Fantasy    -4.553e+08   6.46e+07     -7.045      0.000   -5.82e+08   -3.29e+08
# Thriller   -4.378e+08   7.53e+07     -5.816      0.000   -5.85e+08    -2.9e+08
# Mystery    -4.668e+08   6.88e+07     -6.789      0.000   -6.02e+08   -3.32e+08
# Sci_Fi     -5.017e+08   7.53e+07     -6.666      0.000   -6.49e+08   -3.54e+08
# Romance    -4.891e+08   8.12e+07     -6.024      0.000   -6.48e+08    -3.3e+08
# Western    -4.752e+08   1.23e+08     -3.873      0.000   -7.16e+08   -2.35e+08
# PG_13       1.306e+07   3.93e+06      3.327      0.001    5.37e+06    2.08e+07
# PG          2.152e+07   5.06e+06      4.254      0.000    1.16e+07    3.14e+07
# ==============================================================================
# Omnibus:                     3368.475   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           247002.145
# Skew:                           3.122   Prob(JB):                         0.00
# Kurtosis:                      39.440   Cond. No.                     8.21e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.21e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # would say that the most important variables seem to be genre, rating, votes, budget

# %%
best_fwd_reg_model4 = models_best['model'][18]
best_fwd_reg_model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     497.0
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):               0.00
# Time:                        22:57:42   Log-Likelihood:                -86302.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4318   BIC:                         1.728e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.273e+08   6.17e+07      6.929      0.000    3.06e+08    5.48e+08
# votes        381.4814     10.076     37.862      0.000     361.728     401.235
# budget         2.4850      0.050     49.648      0.000       2.387       2.583
# Comedy      -4.61e+08   6.16e+07     -7.480      0.000   -5.82e+08    -3.4e+08
# Action     -4.767e+08   6.16e+07     -7.733      0.000   -5.98e+08   -3.56e+08
# Drama      -4.722e+08   6.17e+07     -7.650      0.000   -5.93e+08   -3.51e+08
# Biography  -4.829e+08   6.19e+07     -7.798      0.000   -6.04e+08   -3.61e+08
# Horror     -4.369e+08   6.21e+07     -7.037      0.000   -5.59e+08   -3.15e+08
# Adventure  -4.699e+08   6.18e+07     -7.602      0.000   -5.91e+08   -3.49e+08
# Crime      -4.777e+08   6.19e+07     -7.717      0.000   -5.99e+08   -3.56e+08
# Animation  -4.007e+08   6.19e+07     -6.477      0.000   -5.22e+08   -2.79e+08
# Fantasy    -4.552e+08   6.47e+07     -7.036      0.000   -5.82e+08   -3.28e+08
# Thriller   -4.379e+08   7.54e+07     -5.811      0.000   -5.86e+08    -2.9e+08
# Mystery    -4.666e+08   6.88e+07     -6.779      0.000   -6.02e+08   -3.32e+08
# Sci_Fi     -5.017e+08   7.53e+07     -6.659      0.000   -6.49e+08   -3.54e+08
# Romance    -4.892e+08   8.13e+07     -6.019      0.000   -6.49e+08    -3.3e+08
# Western    -4.754e+08   1.23e+08     -3.870      0.000   -7.16e+08   -2.35e+08
# PG_13       1.349e+07   3.93e+06      3.434      0.001    5.79e+06    2.12e+07
# PG          2.191e+07   5.06e+06      4.327      0.000     1.2e+07    3.18e+07
# ==============================================================================
# Omnibus:                     3365.937   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           247647.678
# Skew:                           3.117   Prob(JB):                         0.00
# Kurtosis:                      39.491   Cond. No.                     8.21e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.21e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Finding the RMSE of the model selected using the forward selection procedure, where the predictors
#include 2-factor interactions
pred_gross = best_fwd_reg_model3.predict(test)
np.sqrt(((pred_gross - test.gross)**2).mean())

# this doesn't run cuz the test data does not have a movie of the "Sci_Fi" genre in it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:165, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     164 code = compile(expr, source_name, "eval", self.flags, False)
# --> 165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# File <string>:1, in <module>
#
# NameError: name 'Sci_Fi' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:1137, in Results.predict(self, exog, transform, *args, **kwargs)
#    1136 try:
# -> 1137     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1138 except Exception as exc:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py:290, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     289 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 290 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     291                                   NA_action, return_type)
#     292 if lhs.shape[1] != 0:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py:167, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     166 if design_infos is not None:
# --> 167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#     170 else:
#     171     # No builders, but maybe we can still get matrices
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/build.py:888, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     887 if factor_info not in factor_info_to_values:
# --> 888     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     889     factor_info_to_isNAs[factor_info] = is_NA
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/build.py:63, in _eval_factor(factor_info, data, NA_action)
#      62 factor = factor_info.factor
# ---> 63 result = factor.eval(factor_info.state, data)
#      64 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:564, in EvalFactor.eval(self, memorize_state, data)
#     563 def eval(self, memorize_state, data):
# --> 564     return self._eval(memorize_state["eval_code"],
#     565                       memorize_state,
#     566                       data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:547, in EvalFactor._eval(self, code, memorize_state, data)
#     546 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547 return call_and_wrap_exc("Error evaluating factor",
#     548                          self,
#     549                          memorize_state["eval_env"].eval,
#     550                          code,
#     551                          inner_namespace=inner_namespace)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42     # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43     exec("raise new_exc from e")
#      44 else:
#      45     # In python 2, we just let the original exception escape -- better
#      46     # than destroying the traceback. But if it's a PatsyError, we can
#      47     # at least set the origin properly.
#
# File <string>:1, in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'Sci_Fi' is not defined
#     gross~votes+budget+Germany+Comedy+Action+Drama+Biography+Horror+Adventure+Crime+Animation+Fantasy+Thriller+Mystery+Sci_Fi+Romance+Western+PG_13+PG
#                                                                                                                        ^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       1 #Finding the RMSE of the model selected using the forward selection procedure, where the predictors
#       2 #include 2-factor interactions
# ----> 3 pred_gross = np.exp(best_fwd_reg_model3.predict(test))
#       4 np.sqrt(((pred_gross - test.gross)**2).mean())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:1144, in Results.predict(self, exog, transform, *args, **kwargs)
#    1138 except Exception as exc:
#    1139     msg = ('predict requires that you use a DataFrame when '
#    1140            'predicting from a model\nthat was created using the '
#    1141            'formula api.'
#    1142            '\n\nThe original error message returned by patsy is:\n'
#    1143            '{0}'.format(str(str(exc))))
# -> 1144     raise exc.__class__(msg)
#    1145 if orig_exog_len > len(exog) and not is_dict:
#    1146     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'Sci_Fi' is not defined
#     gross~votes+budget+Germany+Comedy+Action+Drama+Biography+Horror+Adventure+Crime+Animation+Fantasy+Thriller+Mystery+Sci_Fi+Romance+Western+PG_13+PG
#                                                                                                                        ^^^^^^

# %%
test.columns
# Out:
# Index(['name', 'year', 'released', 'score', 'votes', 'director', 'writer',
#        'star', 'budget', 'gross', 'company', 'runtime', 'G', 'NC_17',
#        'Not_Rated', 'PG', 'PG_13', 'R', 'TV_MA', 'Unrated', 'Action',
#        'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama',
#        'Family', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Thriller',
#        'Western', 'Argentina', 'Australia', 'Belgium', 'Brazil', 'Canada',
#        'China', 'Colombia', 'Czech_Republic', 'Denmark', 'France', 'Germany',
#        'Hong_Kong', 'India', 'Indonesia', 'Ireland', 'Italy', 'Japan', 'Malta',
#        'Mexico', 'Netherlands', 'New_Zealand', 'Norway', 'Portugal', 'Russia',
#        'South_Africa', 'South_Korea', 'Spain', 'Sweden', 'Taiwan', 'Thailand',
#        'United_Kingdom', 'United_States'],
#       dtype='object')

# %%
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import r2_score

# %% [markdown]
# ## RIDGE - was not successful - disregard

# %%
y = train.gross

# %%
#Standardizing predictors so that each of them have zero mean and unit variance

# Dropping `United_States`, `Action`, and `PG_13` predictors to avoid multicollinearity
X = train.loc[:,['year','score','votes','budget','runtime','United_States', 'United_Kingdom', 'France', 'Germany', 'Belgium',
       'Spain', 'Japan', 'Australia', 'New_Zealand', 'China', 'Canada',
       'Austria', 'Norway', 'Iceland', 'West_Germany', 'Mexico',
       'Ireland', 'Italy', 'South_Korea', 'Hong_Kong', 'India',
       'United_Arab_Emirates', 'Czech_Republic', 'Finland', 'Taiwan',
       'Lebanon', 'South_Africa', 'Argentina', 'Indonesia', 'Iran',
       'Switzerland', 'Brazil', 'Republic_of_Macedonia', 'Sweden',
       'Russia', 'Netherlands', 'Aruba', 'Jamaica', 'Chile', 'Panama',
       'Denmark', 'Israel', 'Federal_Republic_of_Yugoslavia', 'Kenya',
       'Yugoslavia', 'Hungary','Comedy', 'Action', 'Drama', 'Biography', 'Horror', 'Adventure',
       'Crime', 'Animation', 'Fantasy', 'Thriller', 'Mystery', 'Sci_Fi',
       'Family', 'Romance', 'Western','PG_13', 'R', 'PG', 'Not_Rated', 'G', 'Unrated', 'X', 'NC_17',
       'Approved', 'TV_MA']]

#Defining a scaler object
scaler = StandardScaler()

#The scaler object will contain the mean and variance of each column (predictor) of X. 
#These values will be useful to scale test data based on the same mean and variance as obtained on train data
scaler.fit(X)

#Using the scaler object (or the values of mean and variance stored in it) to standardize X (or train data)
Xstd = scaler.transform(X)

# %%
#The tuning parameter lambda is referred as alpha in sklearn

#Creating a range of values of the tuning parameter to visualize the ridge regression coefficients
#for different values of the tuning parameter
alphas = 10**np.linspace(10,-2,200)*0.5

# %%
#Finding the ridge regression coefficients for increasing values of the tuning parameter
coefs = []
for a in alphas:        
    ridge = Ridge(alpha = a)
    ridge.fit(Xstd, y)
    coefs.append(ridge.coef_)

# %%
#Visualizing the shrinkage in ridge regression coefficients with increasing values of the tuning parameter lambda
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(alphas, coefs)
plt.xscale('log')
plt.xlabel('$\lambda$')
plt.ylabel('Standardized coefficient')
plt.legend(train.columns[1:6]);

# %%
#Let us use cross validation to find the optimal value of the tuning parameter - lambda
#For the optimal lambda, the cross validation error will be the least

#Note that we are reducing the range of alpha so as to better visualize the minimum
alphas = 10**np.linspace(1.5,-3,200)*0.5
ridgecv = RidgeCV(alphas = alphas,store_cv_values=True)
ridgecv.fit(Xstd, y)

#Optimal value of the tuning parameter - lamda
ridgecv.alpha_
# Out:
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1791: RuntimeWarning: invalid value encountered in reciprocal
#   w = ((singvals_sq + alpha) ** -1) - (alpha ** -1)
# 15.811388300841896

# %%
#Visualizing the LOOCV (leave one out cross validatation error vs lambda)
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(ridgecv.alphas,ridgecv.cv_values_.sum(axis=0))
plt.plot([ridgecv.alpha_,ridgecv.alpha_],[40,40.2],':')
plt.xlabel('$\lambda$')
plt.ylabel('Cross-validation error')
# Out:
# Text(0, 0.5, 'Cross-validation error')

# %% [markdown]
# ## LASSO - was not successful - disregard

# %%
#Creating a range of values of the tuning parameter to visualize the lasso coefficients
#for different values of the tuning parameter
alphas = 10**np.linspace(10,-2,100)*0.1

# %%
#Finding the lasso coefficients for increasing values of the tuning parameter
lasso = Lasso(max_iter = 10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(Xstd, y)
    coefs.append(lasso.coef_)
# Out:
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.111e+17, tolerance: 1.500e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.110e+17, tolerance: 1.500e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.110e+17, tolerance: 1.500e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.110e+17, tolerance: 1.500e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.109e+17, tolerance: 1.500e+16
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <cell line: 5>()
#       5 for a in alphas:
#       6     lasso.set_params(alpha=a)
# ----> 7     lasso.fit(Xstd, y)
#       8     coefs.append(lasso.coef_)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:1039, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#    1037 else:
#    1038     this_Xy = None
# -> 1039 _, this_coef, this_dual_gap, this_iter = self.path(
#    1040     X,
#    1041     y[:, k],
#    1042     l1_ratio=self.l1_ratio,
#    1043     eps=None,
#    1044     n_alphas=None,
#    1045     alphas=[alpha],
#    1046     precompute=precompute,
#    1047     Xy=this_Xy,
#    1048     copy_X=True,
#    1049     verbose=False,
#    1050     tol=self.tol,
#    1051     positive=self.positive,
#    1052     X_offset=X_offset,
#    1053     X_scale=X_scale,
#    1054     return_n_iter=True,
#    1055     coef_init=coef_[k],
#    1056     max_iter=self.max_iter,
#    1057     random_state=self.random_state,
#    1058     selection=self.selection,
#    1059     check_input=False,
#    1060 )
#    1061 coef_[k] = this_coef[:, 0]
#    1062 dual_gaps_[k] = this_dual_gap[0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     633     model = cd_fast.enet_coordinate_descent_gram(
#     634         coef_,
#     635         l1_reg,
#    (...)
#     644         positive,
#     645     )
#     646 elif precompute is False:
# --> 647     model = cd_fast.enet_coordinate_descent(
#     648         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     649     )
#     650 else:
#     651     raise ValueError(
#     652         "Precompute should be one of True, False, 'auto' or array-like. Got %r"
#     653         % precompute
#     654     )
#
# File sklearn/linear_model/_cd_fast.pyx:251, in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/getlimits.py:383, in finfo.__new__(cls, dtype)
#     382 def __new__(cls, dtype):
# --> 383     try:
#     384         dtype = numeric.dtype(dtype)
#     385     except TypeError:
#     386         # In case a float instance was given
#
# KeyboardInterrupt:

# %%
#Visualizing the shrinkage in lasso coefficients with increasing values of the tuning parameter lambda
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(alphas, coefs)
plt.xscale('log')
plt.xlabel('$\lambda$')
plt.ylabel('Standardized coefficient')
plt.legend(train.columns[1:6]);
#plt.plot([lassocv.alpha_,lassocv.alpha_],[-0.4,0.25],':')
plt.legend(train.columns[1:6]);

# %%
#Let us use cross validation to find the optimal value of the tuning parameter - lambda
#For the optimal lambda, the cross validation error will be the least

#Note that we are reducing the range of alpha so as to better visualize the minimum
alphas = 10**np.linspace(-1,-5,200)*0.5
lassocv = LassoCV(alphas = alphas, cv = 10, max_iter = 100000)
lassocv.fit(Xstd, y)

#Optimal value of the tuning parameter - lamda
lassocv.alpha_

# %%
#Visualizing the LOOCV (leave one out cross validatation error vs lambda)
plt.xlabel('xlabel', fontsize=18)
plt.ylabel('ylabel', fontsize=18)
plt.plot(lassocv.alphas_,lassocv.mse_path_.mean(axis=1))
plt.plot([lassocv.alpha_,lassocv.alpha_],[0.145,0.151],':')
plt.xlabel('$\lambda$')
plt.ylabel('Cross-validation error')

# %% [markdown]
# ## FORWARD STEPWISE USING CONTINENTS

# %%
def dummies_for_continents(df):
    rating_dummy = pd.get_dummies(df['rating'])
    df = pd.concat([df, rating_dummy], axis=1)
    df = df.drop('rating', axis=1)
    genre_dummy = pd.get_dummies(df['genre'])
    df = pd.concat([df, genre_dummy], axis=1)
    df = df.drop('genre', axis=1)
    continent_dummy = pd.get_dummies(df['continent'])
    df = pd.concat([df, continent_dummy], axis=1)
    df = df.drop('continent', axis=1)
    return df

train = dummies_for_continents(train)
test = dummies_for_continents(test)

# %%
#Creating a set of predictors from which we need to find the best subset of predictors
X = train[['year','score','votes','budget','runtime','North_America', 'Europe', 'Asia', 'Oceania', 'Africa',
       'South_America','Comedy', 'Action', 'Drama', 'Biography', 'Horror', 'Adventure',
       'Crime', 'Animation', 'Fantasy', 'Thriller', 'Mystery', 'Sci_Fi',
       'Family', 'Romance', 'Western','PG_13', 'R', 'PG', 'Not_Rated', 'G', 'Unrated', 'X', 'NC_17',
       'Approved', 'TV_MA']]

# %%
models_best = forward_selection()
# Out:
# Processed  36 models on 1 predictors in 0.2952718734741211 seconds.
# Processed  35 models on 2 predictors in 0.26404619216918945 seconds.
# Processed  34 models on 3 predictors in 0.31867003440856934 seconds.
# Processed  33 models on 4 predictors in 0.35049891471862793 seconds.
# Processed  32 models on 5 predictors in 0.3686378002166748 seconds.
# Processed  31 models on 6 predictors in 0.45598387718200684 seconds.
# Processed  30 models on 7 predictors in 0.42125368118286133 seconds.
# Processed  29 models on 8 predictors in 1.0424277782440186 seconds.
# Processed  28 models on 9 predictors in 0.7187321186065674 seconds.
# Processed  27 models on 10 predictors in 0.6908159255981445 seconds.
# Processed  26 models on 11 predictors in 0.7389049530029297 seconds.
# Processed  25 models on 12 predictors in 0.5834012031555176 seconds.
# Processed  24 models on 13 predictors in 0.8132009506225586 seconds.
# Processed  23 models on 14 predictors in 0.7304379940032959 seconds.
# Processed  22 models on 15 predictors in 0.617311954498291 seconds.
# Processed  21 models on 16 predictors in 0.8522708415985107 seconds.
# Processed  20 models on 17 predictors in 0.6965329647064209 seconds.
# Processed  19 models on 18 predictors in 0.730004072189331 seconds.
# Processed  18 models on 19 predictors in 0.7222170829772949 seconds.
# Processed  17 models on 20 predictors in 1.0688951015472412 seconds.
# Processed  16 models on 21 predictors in 0.8935840129852295 seconds.
# Processed  15 models on 22 predictors in 0.7836389541625977 seconds.
# Processed  14 models on 23 predictors in 0.8621900081634521 seconds.
# Processed  13 models on 24 predictors in 0.9844470024108887 seconds.
# Processed  12 models on 25 predictors in 1.027928113937378 seconds.
# Processed  11 models on 26 predictors in 1.0149388313293457 seconds.
# Processed  10 models on 27 predictors in 1.6244170665740967 seconds.
# Processed  9 models on 28 predictors in 0.8412678241729736 seconds.
# Processed  8 models on 29 predictors in 0.7368052005767822 seconds.
# Processed  7 models on 30 predictors in 0.6014831066131592 seconds.
# Processed  6 models on 31 predictors in 0.4963831901550293 seconds.
# Processed  5 models on 32 predictors in 0.4376509189605713 seconds.
# Processed  4 models on 33 predictors in 0.2236189842224121 seconds.
# Processed  3 models on 34 predictors in 0.1687161922454834 seconds.
# Processed  2 models on 35 predictors in 0.16182613372802734 seconds.
# Processed  1 models on 36 predictors in 0.0629723072052002 seconds.
# Total elapsed time: 23.683705806732178 seconds.

# %%
best_sub_plots()

# %%
best_fwd_reg_model5 = models_best['model'][8]
best_fwd_reg_model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     1120.
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:08:21   Log-Likelihood:                -86304.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4328   BIC:                         1.727e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -2.421e+07      3e+06     -8.058      0.000   -3.01e+07   -1.83e+07
# votes         374.7425     10.063     37.241      0.000     355.015     394.470
# budget          2.4526      0.047     52.742      0.000       2.361       2.544
# Germany      -3.93e+07   1.26e+07     -3.128      0.002   -6.39e+07   -1.47e+07
# New_Zealand  7.233e+07    2.6e+07      2.782      0.005    2.14e+07    1.23e+08
# Horror       3.297e+07   7.76e+06      4.249      0.000    1.78e+07    4.82e+07
# Animation    6.938e+07   7.65e+06      9.067      0.000    5.44e+07    8.44e+07
# Family        4.77e+08   6.14e+07      7.767      0.000    3.57e+08    5.97e+08
# R            -1.88e+07   3.46e+06     -5.437      0.000   -2.56e+07    -1.2e+07
# ==============================================================================
# Omnibus:                     3403.293   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250580.413
# Skew:                           3.174   Prob(JB):                         0.00
# Kurtosis:                      39.693   Cond. No.                     2.09e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## BACKWARD STEPWISE USING CONTINENTS

# %%
models_best = backward_selection()
# Out:
# Processed  36 models on 35 predictors in 2.197654962539673 seconds.
# Processed  35 models on 34 predictors in 2.4277868270874023 seconds.
# Processed  34 models on 33 predictors in 2.9556779861450195 seconds.
# Processed  33 models on 32 predictors in 2.190606117248535 seconds.
# Processed  32 models on 31 predictors in 2.2066121101379395 seconds.
# Processed  31 models on 30 predictors in 1.9492809772491455 seconds.
# Processed  30 models on 29 predictors in 1.6933581829071045 seconds.
# Processed  29 models on 28 predictors in 1.7139551639556885 seconds.
# Processed  28 models on 27 predictors in 1.3548190593719482 seconds.
# Processed  27 models on 26 predictors in 1.762209177017212 seconds.
# Processed  26 models on 25 predictors in 1.4984359741210938 seconds.
# Processed  25 models on 24 predictors in 1.1918909549713135 seconds.
# Processed  24 models on 23 predictors in 1.6887140274047852 seconds.
# Processed  23 models on 22 predictors in 0.9095802307128906 seconds.
# Processed  22 models on 21 predictors in 0.88861083984375 seconds.
# Processed  21 models on 20 predictors in 0.7352848052978516 seconds.
# Processed  20 models on 19 predictors in 0.6882319450378418 seconds.
# Processed  19 models on 18 predictors in 0.6944398880004883 seconds.
# Processed  18 models on 17 predictors in 0.5771439075469971 seconds.
# Processed  17 models on 16 predictors in 0.45345115661621094 seconds.
# Processed  16 models on 15 predictors in 0.4259519577026367 seconds.
# Processed  15 models on 14 predictors in 0.3755199909210205 seconds.
# Processed  14 models on 13 predictors in 0.34105801582336426 seconds.
# Processed  13 models on 12 predictors in 0.27803587913513184 seconds.
# Processed  12 models on 11 predictors in 0.26328110694885254 seconds.
# Processed  11 models on 10 predictors in 0.23938298225402832 seconds.
# Processed  10 models on 9 predictors in 0.26558899879455566 seconds.
# Processed  9 models on 8 predictors in 0.1955091953277588 seconds.
# Processed  8 models on 7 predictors in 0.17257118225097656 seconds.
# Processed  7 models on 6 predictors in 0.08766889572143555 seconds.
# Processed  6 models on 5 predictors in 0.06585192680358887 seconds.
# Processed  5 models on 4 predictors in 0.04941916465759277 seconds.
# Processed  4 models on 3 predictors in 0.051538944244384766 seconds.
# Processed  3 models on 2 predictors in 0.023533105850219727 seconds.
# Processed  2 models on 1 predictors in 0.013561725616455078 seconds.
# Total elapsed time: 32.98941612243652 seconds.

# %%
best_sub_plots()

# %%
best_bwd_reg_model6 = models_best['model'][7]
best_bwd_reg_model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     1277.
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        17:10:20   Log-Likelihood:                -86307.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4329   BIC:                         1.727e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.218e+07   3.09e+06     -7.179      0.000   -2.82e+07   -1.61e+07
# votes        378.0116     10.016     37.740      0.000     358.375     397.649
# budget         2.4416      0.047     52.439      0.000       2.350       2.533
# Europe     -1.528e+07   4.59e+06     -3.330      0.001   -2.43e+07   -6.28e+06
# Horror      3.233e+07   7.77e+06      4.163      0.000    1.71e+07    4.76e+07
# Animation   6.938e+07   7.65e+06      9.066      0.000    5.44e+07    8.44e+07
# Family      4.749e+08   6.14e+07      7.728      0.000    3.54e+08    5.95e+08
# R          -1.908e+07   3.46e+06     -5.515      0.000   -2.59e+07   -1.23e+07
# ==============================================================================
# Omnibus:                     3388.864   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           249227.482
# Skew:                           3.152   Prob(JB):                         0.00
# Kurtosis:                      39.598   Cond. No.                     2.09e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
best_bwd_reg_model7 = models_best['model'][8]
best_bwd_reg_model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     1119.
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        17:10:40   Log-Likelihood:                -86304.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4328   BIC:                         1.727e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -5.15e+07   1.26e+07     -4.089      0.000   -7.62e+07   -2.68e+07
# score       4.827e+06   2.01e+06      2.401      0.016    8.85e+05    8.77e+06
# votes        363.9849     11.591     31.403      0.000     341.261     386.709
# budget         2.4616      0.047     52.069      0.000       2.369       2.554
# Europe     -1.653e+07   4.62e+06     -3.581      0.000   -2.56e+07   -7.48e+06
# Horror      3.527e+07   7.86e+06      4.488      0.000    1.99e+07    5.07e+07
# Animation   6.722e+07    7.7e+06      8.729      0.000    5.21e+07    8.23e+07
# Family      4.727e+08   6.14e+07      7.696      0.000    3.52e+08    5.93e+08
# R          -2.011e+07   3.48e+06     -5.773      0.000   -2.69e+07   -1.33e+07
# ==============================================================================
# Omnibus:                     3391.207   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           246026.270
# Skew:                           3.161   Prob(JB):                         0.00
# Kurtosis:                      39.352   Cond. No.                     2.09e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
