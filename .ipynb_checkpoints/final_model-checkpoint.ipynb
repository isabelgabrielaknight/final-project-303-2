# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import itertools
import time
movies = pd.read_csv('movie_industry_clean.csv')

# %%
# data wrangling
def wrangling(df):
    df = df.drop('Unnamed: 0', axis=1)
    df = df.drop('index', axis=1)
    df.replace(' ', '_', regex=True, inplace = True)
    df.replace('-', '_', regex=True, inplace = True)
    return df

movies = wrangling(movies)

# %%
# grouping countries into continents
def continent(s):
    if s['country'] in ['United_States','Mexico', 'Canada','Jamaica']:
        return 'North_America'
    if s['country'] in ['United_Kingdom', 'France', 'Germany', 'Belgium','Spain', 'Norway', 'Iceland', 'West_Germany', 'Ireland', 'Italy', 'Finland', 'Czech_Republic', 'Switzerland', 'Sweden', 'Denmark', 'Netherlands','Federal_Republic_of_Yugoslavia','Yugoslavia', 'Hungary', 'Republic_of_Macedonia', 'Austria','Portugal','Malta']:
        return 'Europe'
    if s['country'] in ['Japan','China','South_Korea', 'Hong_Kong','India','United_Arab_Emirates','Taiwan','Lebanon','Indonesia', 'Iran','Israel','Russia','Thailand']:
        return 'Asia'
    if s['country'] in ['Australia','New_Zealand']:
        return 'Oceania'
    if s['country'] in ['South_Africa', 'Kenya']:
        return 'Africa'
    if s['country'] in ['Brazil', 'Argentina', 'Aruba', 'Chile', 'Panama','Colombia']:
        return 'South_America'
    else:
        return 'NA'

movies['continent'] = movies.apply(continent, axis=1)

# %%
# split into training & test
np.random.seed(2)
train = movies.sample(round(movies.shape[0]*0.8)) # 80%
test = movies.drop(train.index)

# Resetting the indices for both test and train
train = train.reset_index()
train = train.drop(['index'], axis=1)
test = test.reset_index()
test = test.drop(['index'], axis=1)

# %%
train
# Out:
#                                            name rating      genre  year  \
# 0             I_Now_Pronounce_You_Chuck_&_Larry  PG_13     Comedy  2007
# 1                                     Dead_Heat      R     Action  1988
# 2                              American_Wedding      R     Comedy  2003
# 3            You_Will_Meet_a_Tall_Dark_Stranger      R     Comedy  2010
# 4                                Action_Jackson      R     Action  1988
# ...                                         ...    ...        ...   ...
# 4332                              Gods_of_Egypt  PG_13     Action  2016
# 4333        The_Hobbit:_The_Desolation_of_Smaug  PG_13  Adventure  2013
# 4334                          Leaving_Las_Vegas      R      Drama  1995
# 4335                                   J._Edgar      R  Biography  2011
# 4336  Beastmaster_2:_Through_the_Portal_of_Time  PG_13     Action  1991
#
#                                released  score     votes         director  \
# 0         July_20,_2007_(United_States)    5.9  143000.0     Dennis_Dugan
# 1           May_6,_1988_(United_States)    6.0    7200.0   Mark_Goldblatt
# 2        August_1,_2003_(United_States)    6.3  198000.0      Jesse_Dylan
# 3      October_22,_2010_(United_States)    6.3   44000.0      Woody_Allen
# 4     February_12,_1988_(United_States)    5.4   10000.0  Craig_R._Baxley
# ...                                 ...    ...       ...              ...
# 4332  February_26,_2016_(United_States)    5.4  110000.0      Alex_Proyas
# 4333  December_13,_2013_(United_States)    7.8  615000.0    Peter_Jackson
# 4334   February_9,_1996_(United_States)    7.5  117000.0      Mike_Figgis
# 4335  November_11,_2011_(United_States)    6.5  124000.0   Clint_Eastwood
# 4336    August_30,_1991_(United_States)    4.1    3000.0     Sylvio_Tabet
#
#                   writer               star        country       budget  \
# 0           Barry_Fanaro       Adam_Sandler  United_States   85000000.0
# 1            Terry_Black     Treat_Williams  United_States    5000000.0
# 2              Adam_Herz        Jason_Biggs  United_States   55000000.0
# 3            Woody_Allen    Anthony_Hopkins  United_States   22000000.0
# 4          Robert_Reneau      Carl_Weathers  United_States    7000000.0
# ...                  ...                ...            ...          ...
# 4332         Matt_Sazama   Brenton_Thwaites  United_States  140000000.0
# 4333          Fran_Walsh       Ian_McKellen    New_Zealand  225000000.0
# 4334        John_O'Brien       Nicolas_Cage  United_States    3600000.0
# 4335  Dustin_Lance_Black  Leonardo_DiCaprio  United_States   35000000.0
# 4336        Andre_Norton        Marc_Singer  United_States    6000000.0
#
#             gross                     company  runtime      continent
# 0     187134117.0          Universal_Pictures    115.0  North_America
# 1       3588626.0          New_World_Pictures     86.0  North_America
# 2     232722935.0          Universal_Pictures     96.0  North_America
# 3      36015260.0                    Mediapro     98.0  North_America
# 4      20256975.0  Lorimar_Film_Entertainment     96.0  North_America
# ...           ...                         ...      ...            ...
# 4332  150680864.0                   Pyramania    127.0  North_America
# 4333  959007513.0   Metro_Goldwyn_Mayer_(MGM)    161.0        Oceania
# 4334   32029928.0            Lumiere_Pictures    111.0  North_America
# 4335   84920539.0       Imagine_Entertainment    137.0  North_America
# 4336     869325.0                Les_Films_21    107.0  North_America
#
# [4337 rows x 16 columns]

# %%
# the start of a model by hand - NO INTERACTIONS/TRANSFORMATIONS
ols_object = smf.ols(formula = 'gross~budget+genre+rating+votes+continent+runtime+score+year', data = train)
model = ols_object.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     272.6
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:53:35   Log-Likelihood:                -86289.
# No. Observations:                4337   AIC:                         1.726e+05
# Df Residuals:                    4303   BIC:                         1.729e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -5.257e+08   3.63e+08     -1.448      0.148   -1.24e+09    1.86e+08
# genre[T.Adventure]          6.217e+06   7.74e+06      0.803      0.422   -8.97e+06    2.14e+07
# genre[T.Animation]          6.414e+07   1.01e+07      6.336      0.000    4.43e+07     8.4e+07
# genre[T.Biography]         -1.005e+07   8.08e+06     -1.243      0.214   -2.59e+07    5.79e+06
# genre[T.Comedy]             1.418e+07   4.74e+06      2.992      0.003    4.89e+06    2.35e+07
# genre[T.Crime]             -2.856e+06   7.08e+06     -0.404      0.687   -1.67e+07     1.1e+07
# genre[T.Drama]              1.931e+06   5.63e+06      0.343      0.731    -9.1e+06     1.3e+07
# genre[T.Family]             4.694e+08   6.16e+07      7.621      0.000    3.49e+08     5.9e+08
# genre[T.Fantasy]             2.11e+07   2.01e+07      1.050      0.294   -1.83e+07    6.05e+07
# genre[T.Horror]             4.058e+07   8.46e+06      4.797      0.000     2.4e+07    5.72e+07
# genre[T.Mystery]            1.333e+07   3.09e+07      0.431      0.666   -4.73e+07    7.39e+07
# genre[T.Romance]           -1.125e+07   5.34e+07     -0.211      0.833   -1.16e+08    9.34e+07
# genre[T.Sci_Fi]            -2.413e+07   4.35e+07     -0.554      0.579   -1.09e+08    6.12e+07
# genre[T.Thriller]           3.862e+07   4.36e+07      0.887      0.375   -4.68e+07    1.24e+08
# genre[T.Western]           -3.608e+06   1.06e+08     -0.034      0.973   -2.12e+08    2.05e+08
# rating[T.G]                -7.332e+07   1.07e+08     -0.683      0.495   -2.84e+08    1.37e+08
# rating[T.NC_17]            -7.814e+07   1.12e+08     -0.698      0.485   -2.98e+08    1.41e+08
# rating[T.Not_Rated]        -5.937e+07   1.08e+08     -0.548      0.584   -2.72e+08    1.53e+08
# rating[T.PG]               -5.853e+07   1.07e+08     -0.549      0.583   -2.68e+08    1.51e+08
# rating[T.PG_13]            -6.984e+07   1.07e+08     -0.654      0.513   -2.79e+08    1.39e+08
# rating[T.R]                -8.442e+07   1.07e+08     -0.791      0.429   -2.94e+08    1.25e+08
# rating[T.TV_MA]            -9.248e+07   1.51e+08     -0.613      0.540   -3.88e+08    2.03e+08
# rating[T.Unrated]          -5.807e+07   1.11e+08     -0.523      0.601   -2.76e+08     1.6e+08
# rating[T.X]                -1.215e+08   1.51e+08     -0.805      0.421   -4.17e+08    1.74e+08
# continent[T.Asia]           3.385e+07   6.25e+07      0.541      0.588   -8.87e+07    1.56e+08
# continent[T.Europe]         1.099e+07   6.15e+07      0.179      0.858    -1.1e+08    1.32e+08
# continent[T.North_America]  2.638e+07   6.15e+07      0.429      0.668   -9.41e+07    1.47e+08
# continent[T.Oceania]        3.551e+07   6.32e+07      0.562      0.574   -8.83e+07    1.59e+08
# continent[T.South_America]  2.036e+07   7.52e+07      0.271      0.787   -1.27e+08    1.68e+08
# budget                         2.5002      0.056     44.886      0.000       2.391       2.609
# votes                        363.5786     11.814     30.776      0.000     340.418     386.739
# runtime                    -1.089e+05   1.16e+05     -0.936      0.349   -3.37e+05    1.19e+05
# score                       6.894e+06   2.23e+06      3.087      0.002    2.52e+06    1.13e+07
# year                        2.527e+05   1.72e+05      1.473      0.141   -8.36e+04    5.89e+05
# ==============================================================================
# Omnibus:                     3404.351   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250386.962
# Skew:                           3.176   Prob(JB):                         0.00
# Kurtosis:                      39.677   Cond. No.                     1.33e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Plotting residuals vs fitted values
pred_gross = model.predict(test)
plt.rcParams["figure.figsize"] = (9,6)
sns.set(font_scale=1.25)
ax = sns.scatterplot(x = model.fittedvalues, y=model.resid,color = 'orange')
sns.lineplot(x = [pred_gross.min(),pred_gross.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# removing outliers/influential points

#Computing the leverage statistic for each observation
influence = model.get_influence()
leverage = influence.hat_matrix_diag

out = model.outlier_test()

#Average leverage of points
average_leverage = (model.df_model+1)/model.nobs
average_leverage

#We will remove all observations that have leverage higher than the threshold value.
high_leverage_threshold = 4*average_leverage

#Number of high leverage points in the dataset
print(np.sum(leverage>high_leverage_threshold))

#Dropping influential points from data
train_filtered = train.drop(np.intersect1d(np.where(np.abs(out.student_resid)>3)[0], (np.where(leverage>high_leverage_threshold)[0])))

train_filtered.shape

#Number of points removed as they were influential
print(train.shape[0]-train_filtered.shape[0])
# Out:
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py:2158: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# 124
# 7
# /Users/aarti.pappu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:696: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)

# %%
train_filtered
# Out:
#                                            name rating      genre  year  \
# 0             I_Now_Pronounce_You_Chuck_&_Larry  PG_13     Comedy  2007
# 1                                     Dead_Heat      R     Action  1988
# 2                              American_Wedding      R     Comedy  2003
# 3            You_Will_Meet_a_Tall_Dark_Stranger      R     Comedy  2010
# 4                                Action_Jackson      R     Action  1988
# ...                                         ...    ...        ...   ...
# 4332                              Gods_of_Egypt  PG_13     Action  2016
# 4333        The_Hobbit:_The_Desolation_of_Smaug  PG_13  Adventure  2013
# 4334                          Leaving_Las_Vegas      R      Drama  1995
# 4335                                   J._Edgar      R  Biography  2011
# 4336  Beastmaster_2:_Through_the_Portal_of_Time  PG_13     Action  1991
#
#                                released  score     votes         director  \
# 0         July_20,_2007_(United_States)    5.9  143000.0     Dennis_Dugan
# 1           May_6,_1988_(United_States)    6.0    7200.0   Mark_Goldblatt
# 2        August_1,_2003_(United_States)    6.3  198000.0      Jesse_Dylan
# 3      October_22,_2010_(United_States)    6.3   44000.0      Woody_Allen
# 4     February_12,_1988_(United_States)    5.4   10000.0  Craig_R._Baxley
# ...                                 ...    ...       ...              ...
# 4332  February_26,_2016_(United_States)    5.4  110000.0      Alex_Proyas
# 4333  December_13,_2013_(United_States)    7.8  615000.0    Peter_Jackson
# 4334   February_9,_1996_(United_States)    7.5  117000.0      Mike_Figgis
# 4335  November_11,_2011_(United_States)    6.5  124000.0   Clint_Eastwood
# 4336    August_30,_1991_(United_States)    4.1    3000.0     Sylvio_Tabet
#
#                   writer               star        country       budget  \
# 0           Barry_Fanaro       Adam_Sandler  United_States   85000000.0
# 1            Terry_Black     Treat_Williams  United_States    5000000.0
# 2              Adam_Herz        Jason_Biggs  United_States   55000000.0
# 3            Woody_Allen    Anthony_Hopkins  United_States   22000000.0
# 4          Robert_Reneau      Carl_Weathers  United_States    7000000.0
# ...                  ...                ...            ...          ...
# 4332         Matt_Sazama   Brenton_Thwaites  United_States  140000000.0
# 4333          Fran_Walsh       Ian_McKellen    New_Zealand  225000000.0
# 4334        John_O'Brien       Nicolas_Cage  United_States    3600000.0
# 4335  Dustin_Lance_Black  Leonardo_DiCaprio  United_States   35000000.0
# 4336        Andre_Norton        Marc_Singer  United_States    6000000.0
#
#             gross                     company  runtime      continent
# 0     187134117.0          Universal_Pictures    115.0  North_America
# 1       3588626.0          New_World_Pictures     86.0  North_America
# 2     232722935.0          Universal_Pictures     96.0  North_America
# 3      36015260.0                    Mediapro     98.0  North_America
# 4      20256975.0  Lorimar_Film_Entertainment     96.0  North_America
# ...           ...                         ...      ...            ...
# 4332  150680864.0                   Pyramania    127.0  North_America
# 4333  959007513.0   Metro_Goldwyn_Mayer_(MGM)    161.0        Oceania
# 4334   32029928.0            Lumiere_Pictures    111.0  North_America
# 4335   84920539.0       Imagine_Entertainment    137.0  North_America
# 4336     869325.0                Les_Films_21    107.0  North_America
#
# [4330 rows x 16 columns]

# %%
# model WITH INTERACTIONS/TRANSFORMATIONS
ols_object = smf.ols(formula = 'gross~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)', data = train_filtered)
model = ols_object.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     608.4
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        17:01:20   Log-Likelihood:                -85735.
# No. Observations:                4330   AIC:                         1.715e+05
# Df Residuals:                    4310   BIC:                         1.716e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.0215      0.002     11.237      0.000       0.018       0.025
# genre[T.Adventure]           -0.0315      0.003    -11.180      0.000      -0.037      -0.026
# genre[T.Animation]           -0.0010   9.25e-05    -11.227      0.000      -0.001      -0.001
# genre[T.Biography]            0.0008   6.74e-05     11.242      0.000       0.001       0.001
# genre[T.Comedy]               0.0057      0.001     11.235      0.000       0.005       0.007
# genre[T.Crime]                0.0013      0.000     11.236      0.000       0.001       0.002
# genre[T.Drama]                0.0039      0.000     11.238      0.000       0.003       0.005
# genre[T.Family]            5.678e-06   8.75e-07      6.487      0.000    3.96e-06    7.39e-06
# genre[T.Fantasy]              0.0005   4.66e-05     11.228      0.000       0.000       0.001
# genre[T.Horror]               0.0048      0.000     11.229      0.000       0.004       0.006
# genre[T.Mystery]          -1.698e-05   1.51e-06    -11.242      0.000   -1.99e-05    -1.4e-05
# genre[T.Romance]          -9.868e-06   8.86e-07    -11.144      0.000   -1.16e-05   -8.13e-06
# genre[T.Sci_Fi]            3.972e-06   3.57e-07     11.135      0.000    3.27e-06    4.67e-06
# genre[T.Thriller]          2.078e-05   1.85e-06     11.222      0.000    1.72e-05    2.44e-05
# genre[T.Western]           1.836e-08   7.97e-07      0.023      0.982   -1.54e-06    1.58e-06
# rating[T.G]                  -0.0009   8.11e-05    -11.226      0.000      -0.001      -0.001
# rating[T.NC_17]               0.0002   2.04e-05     11.231      0.000       0.000       0.000
# rating[T.Not_Rated]           0.0003   2.35e-05     11.236      0.000       0.000       0.000
# rating[T.PG]                 -0.0024      0.000    -11.198      0.000      -0.003      -0.002
# rating[T.PG_13]               0.0101      0.001     11.228      0.000       0.008       0.012
# rating[T.R]                   0.0141      0.001     11.236      0.000       0.012       0.017
# rating[T.TV_MA]            2.538e-06   2.25e-07     11.295      0.000     2.1e-06    2.98e-06
# rating[T.Unrated]          4.757e-05   4.23e-06     11.234      0.000    3.93e-05    5.59e-05
# rating[T.X]               -1.801e-05    1.6e-06    -11.221      0.000   -2.12e-05   -1.49e-05
# budget                        0.0197      0.103      0.191      0.848      -0.182       0.222
# budget:genre[T.Adventure]     0.4674      0.098      4.764      0.000       0.275       0.660
# budget:genre[T.Animation]     1.2955      0.081     15.961      0.000       1.136       1.455
# budget:genre[T.Biography]    -0.3839      0.192     -2.000      0.046      -0.760      -0.008
# budget:genre[T.Comedy]        0.2394      0.104      2.299      0.022       0.035       0.444
# budget:genre[T.Crime]        -0.3328      0.187     -1.776      0.076      -0.700       0.035
# budget:genre[T.Drama]         0.2400      0.128      1.878      0.060      -0.010       0.490
# budget:genre[T.Family]       59.7450      9.190      6.501      0.000      41.727      77.763
# budget:genre[T.Fantasy]      -0.6726      0.769     -0.875      0.382      -2.180       0.834
# budget:genre[T.Horror]        0.1051      0.343      0.306      0.759      -0.567       0.778
# budget:genre[T.Mystery]      -0.6086      1.378     -0.442      0.659      -3.309       2.092
# budget:genre[T.Romance]      -0.4878      2.597     -0.188      0.851      -5.579       4.604
# budget:genre[T.Sci_Fi]       -1.3793      1.099     -1.255      0.210      -3.534       0.775
# budget:genre[T.Thriller]      1.0298      2.828      0.364      0.716      -4.514       6.574
# budget:genre[T.Western]      -0.0578      8.761     -0.007      0.995     -17.234      17.118
# score                         0.1001      0.009     11.244      0.000       0.083       0.118
# votes                      1702.4309    151.187     11.260      0.000    1406.027    1998.835
# score:votes                -173.3377     19.248     -9.006      0.000    -211.073    -135.602
# I(budget ** 2)             1.046e-08   4.74e-10     22.037      0.000    9.53e-09    1.14e-08
# I(votes ** 2)                 0.0013      0.000      5.096      0.000       0.001       0.002
# I(score * votes ** 2)        -0.0001   2.91e-05     -4.749      0.000      -0.000   -8.12e-05
# ==============================================================================
# Omnibus:                     2938.072   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           150080.962
# Skew:                           2.624   Prob(JB):                         0.00
# Kurtosis:                      31.361   Cond. No.                     7.05e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.05e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#

# %%
#Plotting residuals vs fitted values
pred_gross = model.predict(test)
plt.rcParams["figure.figsize"] = (9,6)
sns.set(font_scale=1.25)
ax = sns.scatterplot(x = model.fittedvalues, y=model.resid,color = 'orange')
sns.lineplot(x = [pred_gross.min(),pred_gross.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# LOG of the model
ols_object = smf.ols(formula = 'np.log(gross)~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)', data = train)
model_log = ols_object.fit()
model_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(gross)   R-squared:                     -19.061
# Model:                            OLS   Adj. R-squared:                -19.149
# Method:                 Least Squares   F-statistic:                    -215.9
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               1.00
# Time:                        16:37:26   Log-Likelihood:                -15389.
# No. Observations:                4337   AIC:                         3.082e+04
# Df Residuals:                    4317   BIC:                         3.094e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  1.777e-09   1.14e-10     15.607      0.000    1.55e-09       2e-09
# genre[T.Adventure]         1.873e-09   1.21e-10     15.509      0.000    1.64e-09    2.11e-09
# genre[T.Animation]        -7.977e-11   5.12e-12    -15.573      0.000   -8.98e-11   -6.97e-11
# genre[T.Biography]         5.336e-11   3.41e-12     15.644      0.000    4.67e-11       6e-11
# genre[T.Comedy]            4.934e-10   3.16e-11     15.606      0.000    4.31e-10    5.55e-10
# genre[T.Crime]             9.827e-11   6.29e-12     15.615      0.000    8.59e-11    1.11e-10
# genre[T.Drama]             3.485e-10   2.23e-11     15.619      0.000    3.05e-10    3.92e-10
# genre[T.Family]            1.275e-12   8.12e-14     15.696      0.000    1.12e-12    1.43e-12
# genre[T.Fantasy]           4.356e-11    2.8e-12     15.584      0.000    3.81e-11     4.9e-11
# genre[T.Horror]            4.176e-10   2.68e-11     15.586      0.000    3.65e-10     4.7e-10
# genre[T.Mystery]          -5.181e-12   3.34e-13    -15.512      0.000   -5.84e-12   -4.53e-12
# genre[T.Romance]          -8.075e-13   5.43e-14    -14.861      0.000   -9.14e-13   -7.01e-13
# genre[T.Sci_Fi]             1.92e-12   1.23e-13     15.591      0.000    1.68e-12    2.16e-12
# genre[T.Thriller]          1.674e-12   1.06e-13     15.749      0.000    1.47e-12    1.88e-12
# genre[T.Western]           9.943e-14   6.97e-14      1.427      0.154   -3.71e-14    2.36e-13
# rating[T.G]               -8.731e-11   5.61e-12    -15.572      0.000   -9.83e-11   -7.63e-11
# rating[T.NC_17]            1.952e-11   1.25e-12     15.593      0.000    1.71e-11     2.2e-11
# rating[T.Not_Rated]        2.101e-11   1.35e-12     15.614      0.000    1.84e-11    2.36e-11
# rating[T.PG]              -2.481e-10   1.59e-11    -15.565      0.000   -2.79e-10   -2.17e-10
# rating[T.PG_13]            8.882e-10    5.7e-11     15.584      0.000    7.77e-10       1e-09
# rating[T.R]                1.182e-09   7.57e-11     15.613      0.000    1.03e-09    1.33e-09
# rating[T.TV_MA]            1.653e-13   1.04e-14     15.911      0.000    1.45e-13    1.86e-13
# rating[T.Unrated]          3.712e-12   2.38e-13     15.605      0.000    3.25e-12    4.18e-12
# rating[T.X]               -1.677e-12   1.08e-13    -15.556      0.000   -1.89e-12   -1.47e-12
# budget                     2.784e-07   8.79e-09     31.667      0.000    2.61e-07    2.96e-07
# budget:genre[T.Adventure]  1.793e-09   8.58e-09      0.209      0.834    -1.5e-08    1.86e-08
# budget:genre[T.Animation] -1.472e-08   7.09e-09     -2.075      0.038   -2.86e-08   -8.12e-10
# budget:genre[T.Biography]  5.492e-08   1.68e-08      3.275      0.001     2.2e-08    8.78e-08
# budget:genre[T.Comedy]     8.358e-08    9.1e-09      9.183      0.000    6.57e-08    1.01e-07
# budget:genre[T.Crime]      5.979e-08   1.64e-08      3.650      0.000    2.77e-08    9.19e-08
# budget:genre[T.Drama]      7.522e-08   1.11e-08      6.756      0.000    5.34e-08     9.7e-08
# budget:genre[T.Family]    -3.236e-08   5.25e-08     -0.617      0.537   -1.35e-07    7.05e-08
# budget:genre[T.Fantasy]    8.927e-08   6.72e-08      1.328      0.184   -4.25e-08    2.21e-07
# budget:genre[T.Horror]     1.511e-07      3e-08      5.043      0.000    9.24e-08     2.1e-07
# budget:genre[T.Mystery]     2.63e-08   5.17e-08      0.509      0.611    -7.5e-08    1.28e-07
# budget:genre[T.Romance]    4.215e-07   2.27e-07      1.856      0.064   -2.38e-08    8.67e-07
# budget:genre[T.Sci_Fi]      2.33e-08   9.61e-08      0.242      0.809   -1.65e-07    2.12e-07
# budget:genre[T.Thriller]   5.526e-07   2.47e-07      2.234      0.026    6.77e-08    1.04e-06
# budget:genre[T.Western]    1.029e-06   7.66e-07      1.343      0.179   -4.73e-07    2.53e-06
# score                      8.218e-09   5.26e-10     15.632      0.000    7.19e-09    9.25e-09
# votes                         0.0002   1.17e-05     15.659      0.000       0.000       0.000
# score:votes               -1.538e-05    1.5e-06    -10.268      0.000   -1.83e-05   -1.24e-05
# I(budget ** 2)            -1.174e-15   4.05e-17    -29.011      0.000   -1.25e-15   -1.09e-15
# I(votes ** 2)             -4.067e-10   1.71e-11    -23.854      0.000    -4.4e-10   -3.73e-10
# I(score * votes ** 2)       4.31e-11   1.88e-12     22.969      0.000    3.94e-11    4.68e-11
# ==============================================================================
# Omnibus:                      406.936   Durbin-Watson:                   1.436
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              872.030
# Skew:                          -0.594   Prob(JB):                    4.38e-190
# Kurtosis:                       4.848   Cond. No.                     6.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.96e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# log model
sns.scatterplot(x = (model_log.fittedvalues), y=(model_log.resid),color = 'orange')
sns.lineplot(x = [model_log.fittedvalues.min(),model_log.fittedvalues.max()],y = [0,0],color = 'blue')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# SQUARE ROOT of the model
ols_object = smf.ols(formula = 'np.sqrt(gross)~budget*genre+score*votes+rating+I(budget**2)+I(votes**2)+I(score*votes**2)', data = train)
model_log = ols_object.fit()
model_log.summary()
